# %% [markdown]
# ![](http://www.upm.es/sfs/Rectorado/Gabinete%20del%20Rector/Logos/UPM/EscPolitecnica/EscUpmPolit_p.gif "UPM")

# %% [markdown]
# # Trabajo final SITC
# ## Análisis de sentimientos en Twitter

# %% [markdown]
# Departamento de Ingeniería de Sistemas Telemáticos. Universidad Politécnica de Madrid.

# %% [markdown]
# Realizado por:
# - Juan Bermudo Mera
# - Margarita Bolívar Jiménez
# - Lourdes Fernández Nieto
# - Ramón Pérez Hernández
#
# © 2017

# %% [markdown]
# # Clustering aplicado sobre el fichero de tweets

# %% [markdown]
# ## Tabla de contenidos
#
# * [Preparación del dataset](#1.-Preparación-del-dataset)
# 	* [Apertura del fichero Excel y conversión a dataframe](#Apertura-del-fichero-Excel-y-conversión-a-dataframe)
#     * [Tokenización y stemming](#Tokenización-y-stemming)
# * [Clustering con K-means](#2.-Clustering-con-K-means)
#     * [K-means con unigramas](#K-means-con-unigramas)
#     * [K-means con unigramas y bigramas](#K-means-con-unigramas-y-bigramas)
#     * [K-means con unigramas, bigramas y trigramas](#K-means-con-unigramas,-bigramas-y-trigramas)
#     * [Asignación de temas/topics](#Asignación-de-temas/topics)
# * [Topic modeling con LDA](#3.-Topic-modeling-con-LDA)

# %%
# Se importan todas las librerías necesarias (Algunas necesitan instalación con: pip install <nombre_paquete>)

# Procesado del fichero csv
import pandas as pd

# Tokenización y stemming
import nltk
from nltk.corpus import stopwords
from string import punctuation
from nltk.stem import SnowballStemmer
from nltk.tokenize import TweetTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Clustering
from sklearn.cluster import KMeans

# LDA
from gensim import corpora, models

# %% [markdown]
# ## 1. Preparación del dataset

# %% [markdown]
# * ### Apertura del fichero Excel y conversión a dataframe

# %%
tweets = pd.read_excel('ficheros/Preprocesados/tweets_spainGeo.xlsx',header=0,encoding='iso8859_15')

# %%
# Se comprueba que se ha cargado correctamente
tweets.head()
# Out:
#                                              content  Latitude  Longitude
# 0  Regalo para socios: 'Talento a la fuga', el li...    40.416     -3.703
# 1  La recuperación del ‘ladrillo’ dispara el 144,...    40.416     -3.703
# 2  TELEVISIÓN SERIES - Cuenta atrás para conocer ...    40.416     -3.703
# 3  Nuestra taza de hoy es un homenaje a uno de lo...    40.416     -3.703
# 4              @MCadepe nos vemos el 19 de mayooo!!!    40.416     -3.703

# %%
tweets.shape
# Out:
# (26363, 3)

# %% [markdown]
# * ### Tokenización y stemming

# %%
# Se descargan las palabras de parada (stopwords) en español 
nltk.download("stopwords")
spanish_stopwords = stopwords.words('spanish')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/monphdez/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Se obtienen los signos de puntuación de la librería punctuation
non_words = list(punctuation)

# Añadimos signos de puntuación que se usan en español
non_words.extend(['¿', '¡'])
non_words.extend(map(str,range(10)))

# %%
# Se definen las funciones para realizar la tokenización y el stemming
stemmer = SnowballStemmer('spanish')
tknzr = TweetTokenizer(strip_handles=True, reduce_len=True)

def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

def tokenize(text):
    # Eliminamos lo que no sean palabras
    text = ''.join([c for c in text if c not in non_words])
    # Tokenización
    tokens = tknzr.tokenize(text)

    # Stemming
    try:
        stems = stem_tokens(tokens, stemmer)
    except Exception as e:
        print(e)
        print(text)
        stems = ['']
    return stems

# %% [markdown]
# ## 2. Clustering con K-means

# %%
# Definición de la función que realiza el clustering con K-means y muestra los resultados
def kmeans_function(final_cluster, mx_tfidf, tweets, vectorizer, text, r_state):
    for num_clusters in range(5,final_cluster):
        km = KMeans(n_clusters=num_clusters, random_state=r_state)
        km.fit(mx_tfidf)  
        clusters = km.labels_.tolist()  
        tweets["Cluster_" + text + "_" + str(num_clusters)] = clusters
        print('Número de clusters: %d' % (num_clusters))
        print(tweets["Cluster_" + text + "_" + str(num_clusters)].value_counts())

        # Impresión de palabras más frecuentes por grupo.
        order_centroids = km.cluster_centers_.argsort()[:, ::-1]
        for i in range(num_clusters):
            print("Cluster {} : Palabras más frecuentes :".format(i))
            for ind in order_centroids[i, :10]: 
                print(' %s' % vectorizer.get_feature_names()[ind])
            print('')
        print('')

# %%
# Extraemos los tweets y los guardamos en una lista
tweets_text = tweets["content"].tolist()

# %% [markdown]
# * ### K-means con unigramas

# %%
# Convertimos la lista en la matriz Tf-idf
vectorizer_unig = TfidfVectorizer(
                max_df = 0.95,
                max_features = 30000,
                analyzer = 'word',
                tokenizer = tokenize,
                lowercase = True,
                use_idf = True,
                stop_words = spanish_stopwords,
                ngram_range=(1,1))
mx_tfidf_unig = vectorizer_unig.fit_transform(tweets_text)

# %%
# Palabras más frecuentes con las condiciones marcadas (pequeño subconjunto; sólo se verá 
# aquí para mostrar que se han extraido correctamente las features)
print(vectorizer_unig.get_feature_names()[100:110])
# Out:
# ['abrel', 'abren', 'abrepuert', 'abres', 'abri', 'abriend', 'abriendomadr', 'abriendopuert', 'abrig', 'abril']

# %%
mx_tfidf_unig.shape
# Out:
# (26363, 30000)

# %%
# Realización del clustering con k-means
kmeans_function(16, mx_tfidf_unig, tweets, vectorizer_unig, "unig", 3333)
# Out:
# Número de clusters: 5
# 0    17365
# 4     6714
# 3      974
# 2      711
# 1      599
# Name: Cluster_unig_5, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  madr
#  par
#  in
#  mas
#  spain
#  at
#  com
#  tod
#  si
#  im
#
# Cluster 1 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 2 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 3 : Palabras más frecuentes :
#  buen
#  dias
#  seguidor
#  unfollowers
#  tuitutil
#  nuev
#  retir
#  viern
#  madr
#  jardin
#
# Cluster 4 : Palabras más frecuentes :
#  …
#  par
#  mas
#  tod
#  hoy
#  madr
#  com
#  si
#  dia
#  hac
#
#
# Número de clusters: 6
# 1    15172
# 2     6753
# 0     2512
# 4      712
# 5      615
# 3      599
# Name: Cluster_unig_6, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  par
#  …
#  madr
#  tod
#  mejor
#  mas
#  dia
#  com
#  hac
#  hoy
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  mas
#  spain
#  si
#  com
#  via
#  tod
#  nuev
#  mejor
#  graci
#
# Cluster 2 : Palabras más frecuentes :
#  …
#  buen
#  dias
#  tod
#  mas
#  hoy
#  madr
#  com
#  dia
#  si
#
# Cluster 3 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 4 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 5 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
#
# Número de clusters: 7
# 0    16000
# 3     6340
# 1     1115
# 6      837
# 4      761
# 5      711
# 2      599
# Name: Cluster_unig_7, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  madr
#  par
#  mas
#  com
#  si
#  via
#  spain
#  tod
#  mejor
#  dia
#
# Cluster 1 : Palabras más frecuentes :
#  buen
#  dias
#  retir
#  …
#  madr
#  viern
#  jardin
#  dia
#  hoy
#  feliz
#
# Cluster 2 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 3 : Palabras más frecuentes :
#  …
#  par
#  mas
#  tod
#  madr
#  hoy
#  com
#  si
#  dia
#  hac
#
# Cluster 4 : Palabras más frecuentes :
#  in
#  madr
#  at
#  im
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 5 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 6 : Palabras más frecuentes :
#  graci
#  tuitutil
#  unfollowers
#  seguidor
#  nuev
#  …
#  tod
#  segu
#  much
#  devuelv
#
#
# Número de clusters: 8
# 6    12307
# 5     5441
# 0     3012
# 4     2558
# 1     1142
# 7      711
# 3      599
# 2      593
# Name: Cluster_unig_8, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  par
#  buen
#  dias
#  …
#  tod
#  viern
#  hoy
#  dia
#  mejor
#  com
#
# Cluster 1 : Palabras más frecuentes :
#  si
#  …
#  quier
#  com
#  per
#  ver
#  pued
#  mas
#  hac
#  tien
#
# Cluster 2 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 3 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 4 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  retir
#  españ
#  via
#  gran
#  palaci
#  real
#  mas
#
# Cluster 5 : Palabras más frecuentes :
#  …
#  tod
#  mas
#  hoy
#  com
#  dia
#  graci
#  hac
#  vid
#  nuestr
#
# Cluster 6 : Palabras más frecuentes :
#  mas
#  com
#  tod
#  nuev
#  graci
#  via
#  per
#  mejor
#  dia
#  hac
#
# Cluster 7 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
#
# Número de clusters: 9
# 1    12826
# 6     6275
# 5     2405
# 3     1632
# 2     1018
# 8      711
# 4      599
# 0      593
# 7      304
# Name: Cluster_unig_9, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 1 : Palabras más frecuentes :
#  par
#  mas
#  com
#  si
#  via
#  tod
#  graci
#  per
#  hac
#  mejor
#
# Cluster 2 : Palabras más frecuentes :
#  hoy
#  …
#  dia
#  buen
#  par
#  toc
#  dias
#  madr
#  com
#  tod
#
# Cluster 3 : Palabras más frecuentes :
#  sol
#  ser
#  tien
#  …
#  si
#  par
#  tod
#  pued
#  mas
#  per
#
# Cluster 4 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 5 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  retir
#  españ
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  via
#
# Cluster 6 : Palabras más frecuentes :
#  …
#  buen
#  dias
#  par
#  tod
#  mas
#  com
#  si
#  dia
#  mejor
#
# Cluster 7 : Palabras más frecuentes :
#  list
#  reserv
#  whatsapp
#  vip
#  sab
#  tartuf
#  mejor
#  show
#  sal
#  info
#
# Cluster 8 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
#
# Número de clusters: 10
# 5    14210
# 6     5350
# 4     1398
# 0     1349
# 7     1127
# 8      759
# 3      755
# 9      711
# 2      599
# 1      105
# Name: Cluster_unig_10, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  tod
#  list
#  …
#  reserv
#  sab
#  mejor
#  vip
#  whatsapp
#  par
#  madr
#
# Cluster 1 : Palabras más frecuentes :
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  esadelawschool
#  esbes
#  esasti
#  esanchezmolin
#  esalud
#  󾭚
#
# Cluster 2 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 3 : Palabras más frecuentes :
#  graci
#  …
#  much
#  segu
#  tod
#  devuelv
#  follow
#  brev
#  tuitutil
#  buen
#
# Cluster 4 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  par
#  much
#  cad
#  pued
#  men
#  person
#  tod
#
# Cluster 5 : Palabras más frecuentes :
#  madr
#  par
#  buen
#  spain
#  via
#  com
#  dias
#  dia
#  hoy
#  españ
#
# Cluster 6 : Palabras más frecuentes :
#  …
#  par
#  madr
#  hoy
#  com
#  dia
#  buen
#  nuestr
#  nuev
#  hac
#
# Cluster 7 : Palabras más frecuentes :
#  si
#  …
#  quier
#  com
#  per
#  par
#  ver
#  pued
#  hac
#  tien
#
# Cluster 8 : Palabras más frecuentes :
#  in
#  madr
#  at
#  im
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 9 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
#
# Número de clusters: 11
# 9     12116
# 6      5282
# 7      2236
# 3      2176
# 10     1251
# 8       710
# 5       645
# 1       599
# 4       591
# 2       481
# 0       276
# Name: Cluster_unig_11, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  list
#  reserv
#  vip
#  whatsapp
#  sab
#  mejor
#  tartuf
#  show
#  sal
#  new
#
# Cluster 1 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 2 : Palabras más frecuentes :
#  bien
#  segu
#  graci
#  …
#  devuelv
#  follow
#  brev
#  tuitutil
#  si
#  pas
#
# Cluster 3 : Palabras más frecuentes :
#  par
#  …
#  mas
#  dia
#  hac
#  com
#  mejor
#  hoy
#  nuestr
#  madr
#
# Cluster 4 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 5 : Palabras más frecuentes :
#  buen
#  dias
#  viern
#  feliz
#  …
#  hoy
#  dia
#  madr
#  felizviern
#  fin
#
# Cluster 6 : Palabras más frecuentes :
#  …
#  mas
#  hoy
#  com
#  si
#  madr
#  dia
#  mejor
#  nuestr
#  hac
#
# Cluster 7 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  retir
#  españ
#  via
#  gran
#  palaci
#  sol
#  plaz
#
# Cluster 8 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 9 : Palabras más frecuentes :
#  mas
#  si
#  com
#  nuev
#  via
#  per
#  dia
#  hac
#  graci
#  quier
#
# Cluster 10 : Palabras más frecuentes :
#  tod
#  …
#  graci
#  par
#  per
#  madr
#  si
#  mas
#  com
#  mund
#
#
# Número de clusters: 12
# 4     11075
# 2      4548
# 7      2068
# 3      1977
# 5      1366
# 8      1334
# 11     1101
# 9       886
# 10      711
# 0       599
# 1       593
# 6       105
# Name: Cluster_unig_12, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 1 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 2 : Palabras más frecuentes :
#  …
#  hoy
#  com
#  madr
#  buen
#  nuev
#  nuestr
#  mejor
#  hac
#  graci
#
# Cluster 3 : Palabras más frecuentes :
#  par
#  …
#  hac
#  com
#  mejor
#  hoy
#  nuestr
#  buen
#  via
#  madr
#
# Cluster 4 : Palabras más frecuentes :
#  buen
#  com
#  dias
#  via
#  graci
#  per
#  hac
#  mejor
#  hoy
#  quier
#
# Cluster 5 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  much
#  par
#  pued
#  person
#  mejor
#  tod
#  men
#
# Cluster 6 : Palabras más frecuentes :
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  esadelawschool
#  esbes
#  esasti
#  esanchezmolin
#  esalud
#  󾭚
#
# Cluster 7 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  retir
#  españ
#  via
#  palaci
#  gran
#  buen
#  sol
#
# Cluster 8 : Palabras más frecuentes :
#  tod
#  list
#  …
#  reserv
#  sab
#  vip
#  mejor
#  whatsapp
#  tartuf
#  par
#
# Cluster 9 : Palabras más frecuentes :
#  dia
#  …
#  hoy
#  buen
#  tierr
#  feliz
#  madr
#  par
#  com
#  libr
#
# Cluster 10 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 11 : Palabras más frecuentes :
#  si
#  …
#  quier
#  com
#  per
#  ver
#  pued
#  hac
#  par
#  tien
#
#
# Número de clusters: 13
# 0     11127
# 11     4514
# 1      2278
# 4      1991
# 2      1202
# 12     1100
# 3       914
# 9       710
# 8       703
# 5       599
# 7       591
# 10      529
# 6       105
# Name: Cluster_unig_13, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  mas
#  com
#  via
#  graci
#  per
#  mejor
#  dia
#  hac
#  quier
#  nuev
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  españ
#  via
#  gran
#  palaci
#  real
#  sol
#  plaz
#
# Cluster 2 : Palabras más frecuentes :
#  tod
#  …
#  sab
#  graci
#  par
#  madr
#  mas
#  mejor
#  list
#  per
#
# Cluster 3 : Palabras más frecuentes :
#  hoy
#  …
#  dia
#  par
#  toc
#  madr
#  com
#  h
#  hac
#  mas
#
# Cluster 4 : Palabras más frecuentes :
#  par
#  …
#  mejor
#  mas
#  madr
#  com
#  nuestr
#  dia
#  hac
#  list
#
# Cluster 5 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 6 : Palabras más frecuentes :
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  esadelawschool
#  esbes
#  esasti
#  esanchezmolin
#  esalud
#  󾭚
#
# Cluster 7 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 8 : Palabras más frecuentes :
#  buen
#  dias
#  retir
#  viern
#  madr
#  jardin
#  feliz
#  …
#  hoy
#  dia
#
# Cluster 9 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 10 : Palabras más frecuentes :
#  lleg
#  tiemp
#  …
#  par
#  pas
#  hac
#  mas
#  dia
#  com
#  madr
#
# Cluster 11 : Palabras más frecuentes :
#  …
#  mas
#  com
#  mejor
#  madr
#  dia
#  nuestr
#  nuev
#  graci
#  hac
#
# Cluster 12 : Palabras más frecuentes :
#  si
#  …
#  quier
#  com
#  per
#  ver
#  pued
#  mas
#  hac
#  tien
#
#
# Número de clusters: 14
# 0     12870
# 6      4808
# 3      2055
# 10     1381
# 9      1364
# 13      773
# 12      710
# 7       599
# 11      535
# 4       507
# 8       348
# 2       193
# 1       115
# 5       105
# Name: Cluster_unig_14, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  madr
#  spain
#  com
#  via
#  si
#  españ
#  dia
#  per
#  graci
#  sol
#
# Cluster 1 : Palabras más frecuentes :
#  adolf
#  suarez
#  madridbaraj
#  mad
#  aeropuert
#  aenaaeropuert
#  in
#  madr
#  im
#  at
#
# Cluster 2 : Palabras más frecuentes :
#  palaci
#  madr
#  cristal
#  vistalegr
#  real
#  cibel
#  florenceandthemachin
#  deport
#  florenc
#  in
#
# Cluster 3 : Palabras más frecuentes :
#  par
#  …
#  madr
#  mejor
#  com
#  dia
#  hac
#  hoy
#  nuestr
#  via
#
# Cluster 4 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  cosl
#  españ
#  alarcon
#  pozuel
#  estacion
#
# Cluster 5 : Palabras más frecuentes :
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  esadelawschool
#  esbes
#  esasti
#  esanchezmolin
#  esalud
#  󾭚
#
# Cluster 6 : Palabras más frecuentes :
#  …
#  madr
#  com
#  hoy
#  si
#  dia
#  hac
#  nuev
#  nuestr
#  mejor
#
# Cluster 7 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 8 : Palabras más frecuentes :
#  mañan
#  …
#  hoy
#  par
#  madr
#  dia
#  si
#  com
#  buen
#  ser
#
# Cluster 9 : Palabras más frecuentes :
#  tod
#  list
#  …
#  reserv
#  sab
#  vip
#  whatsapp
#  mejor
#  par
#  madr
#
# Cluster 10 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  par
#  cad
#  si
#  pued
#  mejor
#  person
#  bonit
#
# Cluster 11 : Palabras más frecuentes :
#  much
#  …
#  graci
#  mas
#  felic
#  tod
#  par
#  mejor
#  gan
#  dia
#
# Cluster 12 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 13 : Palabras más frecuentes :
#  buen
#  dias
#  retir
#  viern
#  madr
#  jardin
#  feliz
#  …
#  hoy
#  dia
#
#
# Número de clusters: 15
# 9     10019
# 8      5442
# 12     2088
# 6      1620
# 7      1386
# 11     1347
# 10      711
# 4       711
# 14      599
# 2       578
# 13      553
# 0       488
# 3       399
# 1       308
# 5       114
# Name: Cluster_unig_15, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  cosl
#  españ
#  alarcon
#  pozuel
#  estacion
#
# Cluster 1 : Palabras más frecuentes :
#  unfollowers
#  list
#  seguidor
#  tuitutil
#  nuev
#  reserv
#  vip
#  whatsapp
#  sab
#  tartuf
#
# Cluster 2 : Palabras más frecuentes :
#  nuestr
#  …
#  par
#  tod
#  app
#  mejor
#  seseñ
#  hoy
#  disfrut
#  mas
#
# Cluster 3 : Palabras más frecuentes :
#  ver
#  …
#  si
#  par
#  quier
#  pued
#  com
#  madr
#  tod
#  hac
#
# Cluster 4 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 5 : Palabras más frecuentes :
#  madridbaraj
#  adolf
#  suarez
#  mad
#  aeropuert
#  aenaaeropuert
#  in
#  madr
#  im
#  at
#
# Cluster 6 : Palabras más frecuentes :
#  com
#  graci
#  …
#  tod
#  par
#  much
#  si
#  segu
#  hac
#  per
#
# Cluster 7 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  much
#  par
#  pued
#  si
#  mejor
#  hac
#  cad
#
# Cluster 8 : Palabras más frecuentes :
#  …
#  par
#  tod
#  si
#  mejor
#  nuev
#  hac
#  per
#  madr
#  sol
#
# Cluster 9 : Palabras más frecuentes :
#  si
#  via
#  tod
#  per
#  mejor
#  quier
#  hac
#  tien
#  nuev
#  pued
#
# Cluster 10 : Palabras más frecuentes :
#  buen
#  dias
#  retir
#  viern
#  madr
#  jardin
#  feliz
#  …
#  hoy
#  felizviern
#
# Cluster 11 : Palabras más frecuentes :
#  dia
#  hoy
#  …
#  par
#  madr
#  tierr
#  feliz
#  tod
#  libr
#  celebr
#
# Cluster 12 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  españ
#  via
#  gran
#  palaci
#  sol
#  plaz
#  adecc
#
# Cluster 13 : Palabras más frecuentes :
#  porqu
#  aqu
#  …
#  tod
#  si
#  par
#  ayudamosaqui
#  som
#  ser
#  necesit
#
# Cluster 14 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient

# %%
# Nueva prueba de clustering con k-means, al detectarse otros grupos con otra semilla
kmeans_function(16, mx_tfidf_unig, tweets, vectorizer_unig, "unig2", 4444)
# Out:
# Número de clusters: 5
# 0    22282
# 3     2467
# 4      712
# 1      599
# 2      303
# Name: Cluster_unig2_5, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  …
#  madr
#  mas
#  buen
#  tod
#  com
#  in
#  si
#  hoy
#  dia
#
# Cluster 1 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 2 : Palabras más frecuentes :
#  list
#  reserv
#  whatsapp
#  vip
#  sab
#  tartuf
#  mejor
#  show
#  sal
#  info
#
# Cluster 3 : Palabras más frecuentes :
#  par
#  …
#  madr
#  tod
#  mas
#  dia
#  com
#  hac
#  buen
#  hoy
#
# Cluster 4 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
#
# Número de clusters: 6
# 4    15143
# 3     6245
# 0     1837
# 2     1551
# 5      988
# 1      599
# Name: Cluster_unig2_6, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  madr
#  tendenci
#  ahor
#  spain
#  in
#  at
#  im
#  comun
#  españ
#  aeropuert
#
# Cluster 1 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 2 : Palabras más frecuentes :
#  tod
#  list
#  …
#  reserv
#  sab
#  mejor
#  vip
#  whatsapp
#  par
#  madr
#
# Cluster 3 : Palabras más frecuentes :
#  …
#  par
#  mas
#  nuev
#  madr
#  hoy
#  com
#  si
#  dia
#  hac
#
# Cluster 4 : Palabras más frecuentes :
#  madr
#  par
#  mas
#  com
#  si
#  via
#  dia
#  per
#  graci
#  hac
#
# Cluster 5 : Palabras más frecuentes :
#  buen
#  dias
#  retir
#  madr
#  viern
#  …
#  jardin
#  feliz
#  dia
#  hoy
#
#
# Número de clusters: 7
# 0    16127
# 3     6311
# 1     1468
# 5      711
# 6      616
# 4      599
# 2      531
# Name: Cluster_unig2_7, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  madr
#  par
#  buen
#  spain
#  tod
#  com
#  dias
#  via
#  si
#  mejor
#
# Cluster 1 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  par
#  much
#  cad
#  pued
#  mejor
#  tod
#  si
#
# Cluster 2 : Palabras más frecuentes :
#  tien
#  …
#  si
#  aqu
#  tod
#  par
#  mas
#  q
#  porqu
#  cuand
#
# Cluster 3 : Palabras más frecuentes :
#  …
#  par
#  tod
#  nuev
#  hoy
#  madr
#  com
#  dia
#  si
#  buen
#
# Cluster 4 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 5 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 6 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
#
# Número de clusters: 8
# 3    19831
# 0     1457
# 2     1110
# 1     1026
# 4      875
# 6      755
# 5      710
# 7      599
# Name: Cluster_unig2_8, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  tod
#  list
#  …
#  sab
#  reserv
#  mejor
#  whatsapp
#  vip
#  par
#  tartuf
#
# Cluster 1 : Palabras más frecuentes :
#  buen
#  dias
#  retir
#  …
#  viern
#  madr
#  jardin
#  feliz
#  hoy
#  par
#
# Cluster 2 : Palabras más frecuentes :
#  si
#  …
#  quier
#  com
#  per
#  ver
#  pued
#  par
#  mas
#  hac
#
# Cluster 3 : Palabras más frecuentes :
#  …
#  madr
#  par
#  mas
#  com
#  nuev
#  hoy
#  via
#  spain
#  mejor
#
# Cluster 4 : Palabras más frecuentes :
#  dia
#  …
#  hoy
#  madr
#  tierr
#  par
#  feliz
#  buen
#  mas
#  com
#
# Cluster 5 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 6 : Palabras más frecuentes :
#  in
#  madr
#  at
#  im
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 7 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
#
# Número de clusters: 9
# 8    14419
# 0     5412
# 6     1769
# 2     1182
# 4      783
# 5      749
# 7      740
# 1      710
# 3      599
# Name: Cluster_unig2_9, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  …
#  par
#  mas
#  madr
#  hoy
#  dia
#  si
#  mejor
#  nuestr
#  nuev
#
# Cluster 1 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 2 : Palabras más frecuentes :
#  com
#  …
#  si
#  par
#  madr
#  per
#  dia
#  quier
#  tod
#  hoy
#
# Cluster 3 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 4 : Palabras más frecuentes :
#  hac
#  …
#  par
#  com
#  mas
#  si
#  falt
#  cuand
#  años
#  per
#
# Cluster 5 : Palabras más frecuentes :
#  buen
#  dias
#  retir
#  viern
#  madr
#  jardin
#  feliz
#  …
#  hoy
#  dia
#
# Cluster 6 : Palabras más frecuentes :
#  tod
#  graci
#  …
#  par
#  much
#  madr
#  sab
#  segu
#  mas
#  mejor
#
# Cluster 7 : Palabras más frecuentes :
#  in
#  at
#  madr
#  im
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 8 : Palabras más frecuentes :
#  madr
#  par
#  mas
#  via
#  spain
#  si
#  nuev
#  mejor
#  dia
#  españ
#
#
# Número de clusters: 10
# 0    12909
# 2     5724
# 5     2232
# 9     1407
# 6     1122
# 8      778
# 7      711
# 1      599
# 4      592
# 3      289
# Name: Cluster_unig2_10, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  par
#  com
#  tod
#  nuev
#  via
#  graci
#  per
#  dia
#  hac
#  hoy
#
# Cluster 1 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 2 : Palabras más frecuentes :
#  …
#  par
#  tod
#  hoy
#  com
#  dia
#  madr
#  nuestr
#  hac
#  graci
#
# Cluster 3 : Palabras más frecuentes :
#  list
#  reserv
#  whatsapp
#  vip
#  sab
#  tartuf
#  mejor
#  show
#  sal
#  info
#
# Cluster 4 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 5 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  españ
#  via
#  gran
#  palaci
#  sol
#  plaz
#  real
#
# Cluster 6 : Palabras más frecuentes :
#  si
#  …
#  quier
#  com
#  per
#  ver
#  par
#  pued
#  hac
#  tien
#
# Cluster 7 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 8 : Palabras más frecuentes :
#  buen
#  dias
#  retir
#  viern
#  madr
#  jardin
#  feliz
#  …
#  hoy
#  dia
#
# Cluster 9 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  much
#  par
#  cad
#  pued
#  men
#  person
#  tod
#
#
# Número de clusters: 11
# 0     11410
# 2      4910
# 10     2733
# 8      2323
# 9      1263
# 1      1219
# 4       710
# 7       599
# 3       593
# 5       498
# 6       105
# Name: Cluster_unig2_11, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  mas
#  si
#  via
#  graci
#  per
#  mejor
#  quier
#  hac
#  dia
#  hoy
#
# Cluster 1 : Palabras más frecuentes :
#  com
#  …
#  si
#  par
#  hac
#  per
#  hoy
#  dia
#  quier
#  tod
#
# Cluster 2 : Palabras más frecuentes :
#  …
#  mas
#  hoy
#  si
#  dia
#  madr
#  nuestr
#  mejor
#  hac
#  nuev
#
# Cluster 3 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 4 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 5 : Palabras más frecuentes :
#  siempr
#  estadi
#  vicent
#  calderon
#  …
#  santiag
#  bernabeu
#  madr
#  mejor
#  atleti
#
# Cluster 6 : Palabras más frecuentes :
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  esadelawschool
#  esbes
#  esasti
#  esanchezmolin
#  esalud
#  󾭚
#
# Cluster 7 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 8 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  retir
#  españ
#  via
#  gran
#  palaci
#  buen
#  sol
#
# Cluster 9 : Palabras más frecuentes :
#  tod
#  …
#  sab
#  graci
#  par
#  madr
#  mas
#  list
#  mejor
#  dias
#
# Cluster 10 : Palabras más frecuentes :
#  par
#  buen
#  dias
#  …
#  viern
#  dia
#  hoy
#  mejor
#  mas
#  hac
#
#
# Número de clusters: 12
# 0     10672
# 2      4512
# 10     2576
# 8      2132
# 11     1505
# 9      1242
# 1      1221
# 4       710
# 7       599
# 3       593
# 5       496
# 6       105
# Name: Cluster_unig2_12, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  si
#  via
#  graci
#  per
#  quier
#  hoy
#  hac
#  dia
#  mejor
#  ser
#
# Cluster 1 : Palabras más frecuentes :
#  com
#  …
#  si
#  par
#  hac
#  per
#  hoy
#  dia
#  tod
#  quier
#
# Cluster 2 : Palabras más frecuentes :
#  …
#  hoy
#  si
#  dia
#  madr
#  nuev
#  nuestr
#  hac
#  mejor
#  noch
#
# Cluster 3 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 4 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 5 : Palabras más frecuentes :
#  siempr
#  estadi
#  vicent
#  calderon
#  …
#  santiag
#  bernabeu
#  madr
#  mejor
#  atleti
#
# Cluster 6 : Palabras más frecuentes :
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  esadelawschool
#  esbes
#  esasti
#  esanchezmolin
#  esalud
#  󾭚
#
# Cluster 7 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 8 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  retir
#  españ
#  via
#  palaci
#  gran
#  buen
#  sol
#
# Cluster 9 : Palabras más frecuentes :
#  tod
#  …
#  graci
#  sab
#  par
#  madr
#  mejor
#  dias
#  per
#  list
#
# Cluster 10 : Palabras más frecuentes :
#  par
#  buen
#  dias
#  …
#  viern
#  dia
#  hoy
#  mejor
#  seman
#  hac
#
# Cluster 11 : Palabras más frecuentes :
#  mas
#  …
#  list
#  reserv
#  mejor
#  whatsapp
#  madr
#  vip
#  sab
#  par
#
#
# Número de clusters: 13
# 0     11141
# 11     5334
# 5      2143
# 1      2059
# 3      1260
# 10     1191
# 7       710
# 2       599
# 6       591
# 9       545
# 12      419
# 4       266
# 8       105
# Name: Cluster_unig2_13, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  mas
#  si
#  graci
#  via
#  per
#  quier
#  dia
#  hac
#  hoy
#  mejor
#
# Cluster 1 : Palabras más frecuentes :
#  par
#  …
#  mas
#  dia
#  hoy
#  mejor
#  nuestr
#  buen
#  hac
#  madr
#
# Cluster 2 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 3 : Palabras más frecuentes :
#  tod
#  …
#  par
#  graci
#  dias
#  buen
#  madr
#  si
#  per
#  mas
#
# Cluster 4 : Palabras más frecuentes :
#  list
#  reserv
#  vip
#  whatsapp
#  sab
#  tartuf
#  mejor
#  show
#  sal
#  info
#
# Cluster 5 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  retir
#  españ
#  palaci
#  buen
#  sol
#  plaz
#  parqu
#
# Cluster 6 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 7 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 8 : Palabras más frecuentes :
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  esadelawschool
#  esbes
#  esasti
#  esanchezmolin
#  esalud
#  󾭚
#
# Cluster 9 : Palabras más frecuentes :
#  stigmab
#  años
#  …
#  pobrez
#  mas
#  vih
#  person
#  drogadiccion
#  homosexual
#  gay
#
# Cluster 10 : Palabras más frecuentes :
#  com
#  …
#  si
#  par
#  hac
#  per
#  hoy
#  dia
#  quier
#  madr
#
# Cluster 11 : Palabras más frecuentes :
#  …
#  buen
#  dias
#  mas
#  hoy
#  dia
#  si
#  madr
#  mejor
#  hac
#
# Cluster 12 : Palabras más frecuentes :
#  gran
#  via
#  madr
#  españ
#  …
#  hoy
#  graci
#  dia
#  par
#  mas
#
#
# Número de clusters: 14
# 0     10023
# 13     5662
# 8      2349
# 11     1369
# 9      1126
# 1      1109
# 2      1067
# 4       710
# 10      627
# 7       599
# 3       593
# 12      542
# 5       482
# 6       105
# Name: Cluster_unig2_14, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  via
#  graci
#  per
#  dia
#  nuev
#  hac
#  mejor
#  hoy
#  quier
#  ser
#
# Cluster 1 : Palabras más frecuentes :
#  com
#  …
#  par
#  hac
#  hoy
#  dia
#  per
#  quier
#  madr
#  tod
#
# Cluster 2 : Palabras más frecuentes :
#  si
#  …
#  quier
#  per
#  com
#  ver
#  pued
#  par
#  hac
#  ser
#
# Cluster 3 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 4 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 5 : Palabras más frecuentes :
#  siempr
#  estadi
#  vicent
#  calderon
#  …
#  santiag
#  bernabeu
#  madr
#  atleti
#  par
#
# Cluster 6 : Palabras más frecuentes :
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  esadelawschool
#  esbes
#  esasti
#  esanchezmolin
#  esalud
#  󾭚
#
# Cluster 7 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 8 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  retir
#  españ
#  …
#  via
#  gran
#  palaci
#  sol
#
# Cluster 9 : Palabras más frecuentes :
#  tod
#  …
#  par
#  sab
#  graci
#  madr
#  list
#  mejor
#  esper
#  vid
#
# Cluster 10 : Palabras más frecuentes :
#  buen
#  dias
#  viern
#  feliz
#  …
#  hoy
#  dia
#  felizviern
#  madr
#  fin
#
# Cluster 11 : Palabras más frecuentes :
#  mas
#  list
#  …
#  reserv
#  whatsapp
#  mejor
#  madr
#  vip
#  par
#  sab
#
# Cluster 12 : Palabras más frecuentes :
#  much
#  …
#  graci
#  mas
#  felic
#  tod
#  par
#  mejor
#  gan
#  per
#
# Cluster 13 : Palabras más frecuentes :
#  …
#  par
#  hoy
#  dia
#  nuestr
#  nuev
#  hac
#  mejor
#  sol
#  pas
#
#
# Número de clusters: 15
# 3     10443
# 10     4378
# 4      2077
# 7      2073
# 0      1944
# 9      1176
# 12      764
# 6       710
# 8       707
# 1       599
# 5       591
# 2       375
# 13      266
# 14      155
# 11      105
# Name: Cluster_unig2_15, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  mas
#  si
#  …
#  quier
#  pued
#  much
#  com
#  hac
#  madr
#  ser
#
# Cluster 1 : Palabras más frecuentes :
#  dgtmadr
#  dgt
#  nivel
#  autov
#  pk
#  autop
#  retencion
#  amarill
#  decrecient
#  crecient
#
# Cluster 2 : Palabras más frecuentes :
#  siempr
#  …
#  com
#  par
#  mejor
#  mas
#  graci
#  madr
#  per
#  nunc
#
# Cluster 3 : Palabras más frecuentes :
#  com
#  via
#  graci
#  dia
#  mejor
#  hoy
#  hac
#  nuev
#  quier
#  pas
#
# Cluster 4 : Palabras más frecuentes :
#  madr
#  spain
#  in
#  españ
#  via
#  gran
#  palaci
#  plaz
#  sol
#  adecc
#
# Cluster 5 : Palabras más frecuentes :
#  at
#  im
#  in
#  madr
#  comun
#  madridbaraj
#  mad
#  adolf
#  aenaaeropuert
#  suarez
#
# Cluster 6 : Palabras más frecuentes :
#  tendenci
#  ahor
#  spain
#  madr
#  tiempodejueg
#  visavis
#  nadal
#  sv
#  manoslimpi
#  fatim
#
# Cluster 7 : Palabras más frecuentes :
#  par
#  …
#  dia
#  hac
#  mas
#  com
#  mejor
#  nuestr
#  hoy
#  madr
#
# Cluster 8 : Palabras más frecuentes :
#  buen
#  dias
#  retir
#  viern
#  madr
#  jardin
#  feliz
#  …
#  hoy
#  dia
#
# Cluster 9 : Palabras más frecuentes :
#  tod
#  …
#  graci
#  par
#  madr
#  sab
#  com
#  mas
#  mund
#  hac
#
# Cluster 10 : Palabras más frecuentes :
#  …
#  hoy
#  com
#  madr
#  dia
#  nuev
#  nuestr
#  hac
#  mejor
#  graci
#
# Cluster 11 : Palabras más frecuentes :
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  esadelawschool
#  esbes
#  esasti
#  esanchezmolin
#  esalud
#  󾭚
#
# Cluster 12 : Palabras más frecuentes :
#  per
#  …
#  si
#  com
#  tod
#  par
#  ser
#  quier
#  hac
#  pued
#
# Cluster 13 : Palabras más frecuentes :
#  list
#  reserv
#  vip
#  whatsapp
#  sab
#  tartuf
#  mejor
#  show
#  sal
#  info
#
# Cluster 14 : Palabras más frecuentes :
#  h
#  c
#  temperatur
#  kmh
#  °
#  vient
#  hpa
#  mm
#  hr
#  precipit

# %%
# Se comprueba que las columnas se han añadido correctamente
tweets.head()
# Out:
#                                              content  Latitude  Longitude  \
# 0  Regalo para socios: 'Talento a la fuga', el li...    40.416     -3.703
# 1  La recuperación del ‘ladrillo’ dispara el 144,...    40.416     -3.703
# 2  TELEVISIÓN SERIES - Cuenta atrás para conocer ...    40.416     -3.703
# 3  Nuestra taza de hoy es un homenaje a uno de lo...    40.416     -3.703
# 4              @MCadepe nos vemos el 19 de mayooo!!!    40.416     -3.703
#
#    Cluster_unig_5  Cluster_unig_6  Cluster_unig_7  Cluster_unig_8  \
# 0               0               0               0               0
# 1               0               1               0               6
# 2               0               0               0               0
# 3               0               1               0               6
# 4               0               1               0               6
#
#    Cluster_unig_9  Cluster_unig_10  Cluster_unig_11        ...         \
# 0               1                5                3        ...
# 1               1                5                9        ...
# 2               1                5                3        ...
# 3               2                4                9        ...
# 4               1                5                9        ...
#
#    Cluster_unig2_6  Cluster_unig2_7  Cluster_unig2_8  Cluster_unig2_9  \
# 0                4                0                3                8
# 1                4                0                3                8
# 2                4                0                3                8
# 3                4                1                3                4
# 4                4                0                3                8
#
#    Cluster_unig2_10  Cluster_unig2_11  Cluster_unig2_12  Cluster_unig2_13  \
# 0                 0                10                10                 1
# 1                 0                 0                 0                 0
# 2                 0                10                10                 1
# 3                 9                 0                11                 0
# 4                 0                 0                 0                 0
#
#    Cluster_unig2_14  Cluster_unig2_15
# 0                13                 7
# 1                 0                 3
# 2                13                 7
# 3                11                 0
# 4                 0                 3
#
# [5 rows x 25 columns]

# %% [markdown]
# * ### K-means con unigramas y bigramas

# %%
# Convertimos la lista en la matriz Tf-idf
vectorizer_unibi = TfidfVectorizer(
                max_df = 0.95,
                min_df = 0.00005,
                max_features = 30000,
                analyzer = 'word',
                tokenizer = tokenize,
                lowercase = True,
                use_idf = True,
                stop_words = spanish_stopwords,
                ngram_range=(1,2))
mx_tfidf_unibi = vectorizer_unibi.fit_transform(tweets_text)

# %%
mx_tfidf_unibi.shape
# Out:
# (26363, 30000)

# %%
# Realización del clustering con k-means
kmeans_function(16, mx_tfidf_unibi, tweets, vectorizer_unibi, "unibi", 3333)
# Out:
# Número de clusters: 5
# 1    18115
# 0     6850
# 4      703
# 3      590
# 2      105
# Name: Cluster_unibi_5, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  …
#  par
#  mas
#  tod
#  madr
#  hoy
#  com
#  dia
#  si
#  buen
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  par
#  buen
#  in
#  mas
#  com
#  spain
#  tod
#  si
#  in madr
#
# Cluster 2 : Palabras más frecuentes :
#  unfollowers tuitutil
#  nuev seguidor
#  seguidor unfollowers
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  ey
#  facult cc
#  factor
#
# Cluster 3 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 4 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
#
# Número de clusters: 6
# 1    19776
# 4     3563
# 2      984
# 5      747
# 0      703
# 3      590
# Name: Cluster_unibi_6, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
# Cluster 1 : Palabras más frecuentes :
#  …
#  madr
#  buen
#  com
#  in
#  si
#  tod
#  hoy
#  dias
#  spain
#
# Cluster 2 : Palabras más frecuentes :
#  mejor
#  list
#  reserv
#  …
#  vip
#  sab
#  whatsapp
#  list vip
#  madr
#  sal
#
# Cluster 3 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 4 : Palabras más frecuentes :
#  par
#  mas
#  …
#  madr
#  tod
#  dia
#  hac
#  com
#  si
#  hoy
#
# Cluster 5 : Palabras más frecuentes :
#  graci
#  …
#  much graci
#  much
#  graci segu
#  segu
#  tod
#  graci tod
#  follow tuitutil
#  devuelv follow
#
#
# Número de clusters: 7
# 1    15942
# 6     5981
# 5     2458
# 0      703
# 4      590
# 2      577
# 3      112
# Name: Cluster_unibi_7, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  in
#  spain
#  mas
#  com
#  si
#  tod
#  madr spain
#  via
#  in madr
#
# Cluster 2 : Palabras más frecuentes :
#  dias
#  buen dias
#  buen
#  retir
#  viern
#  jardin buen
#  buen retir
#  retir jardin
#  jardin
#  retir madr
#
# Cluster 3 : Palabras más frecuentes :
#  aeropuert adolf
#  suarez madridbaraj
#  madridbaraj
#  madridbaraj mad
#  adolf suarez
#  adolf
#  suarez
#  mad
#  mad aenaaeropuert
#  aenaaeropuert
#
# Cluster 4 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 5 : Palabras más frecuentes :
#  par
#  …
#  tod
#  madr
#  mejor
#  mas
#  com
#  hac
#  dia
#  hoy
#
# Cluster 6 : Palabras más frecuentes :
#  …
#  mas
#  madr
#  tod
#  hoy
#  com
#  si
#  dia
#  graci
#  mejor
#
#
# Número de clusters: 8
# 1    14339
# 7     5360
# 0     2403
# 6     1475
# 2      764
# 4      729
# 5      703
# 3      590
# Name: Cluster_unibi_8, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  par
#  …
#  nuev
#  seguidor
#  seguidor unfollowers
#  nuev seguidor
#  unfollowers
#  unfollowers tuitutil
#  tuitutil
#  tod
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  buen
#  com
#  spain
#  si
#  dias
#  via
#  tod
#  madr spain
#  buen dias
#
# Cluster 2 : Palabras más frecuentes :
#  in
#  in madr
#  at
#  im at
#  im
#  madr
#  comun madr
#  comun
#  madr comun
#  madridbaraj mad
#
# Cluster 3 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 4 : Palabras más frecuentes :
#  graci
#  …
#  much graci
#  much
#  graci segu
#  segu
#  tod
#  graci tod
#  follow tuitutil
#  brev devuelv
#
# Cluster 5 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
# Cluster 6 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  much mas
#  much
#  par
#  cad
#  si
#  mas …
#  mas bonit
#
# Cluster 7 : Palabras más frecuentes :
#  …
#  madr
#  hoy
#  tod
#  com
#  si
#  dia
#  buen
#  nuev
#  hac
#
#
# Número de clusters: 9
# 1    15688
# 3     6141
# 6     1142
# 0      768
# 4      717
# 8      703
# 2      590
# 7      509
# 5      105
# Name: Cluster_unibi_9, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  in
#  in madr
#  at
#  im at
#  madr
#  im
#  comun madr
#  comun
#  madr comun
#  aeropuert adolf
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  par
#  mas
#  com
#  spain
#  via
#  tod
#  madr spain
#  mejor
#  dia
#
# Cluster 2 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 3 : Palabras más frecuentes :
#  …
#  par
#  madr
#  mas
#  hoy
#  tod
#  com
#  dia
#  nuestr
#  hac
#
# Cluster 4 : Palabras más frecuentes :
#  graci
#  …
#  much graci
#  much
#  graci segu
#  segu
#  tod
#  graci tod
#  brev devuelv
#  devuelv follow
#
# Cluster 5 : Palabras más frecuentes :
#  unfollowers tuitutil
#  nuev seguidor
#  seguidor unfollowers
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  ey
#  facult cc
#  factor
#
# Cluster 6 : Palabras más frecuentes :
#  si
#  …
#  quier
#  com
#  per
#  ver si
#  ver
#  pued
#  si quier
#  par
#
# Cluster 7 : Palabras más frecuentes :
#  buen dias
#  dias
#  buen
#  viern
#  feliz
#  hoy
#  …
#  felizviern
#  dias amig
#  dias feliz
#
# Cluster 8 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
#
# Número de clusters: 10
# 1    13880
# 7     5347
# 8     2300
# 6     1451
# 9      741
# 4      718
# 5      703
# 3      590
# 2      528
# 0      105
# Name: Cluster_unibi_10, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  unfollowers tuitutil
#  nuev seguidor
#  seguidor unfollowers
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  ey
#  facult cc
#  factor
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  buen
#  com
#  si
#  dias
#  via
#  tod
#  buen dias
#  mejor
#  dia
#
# Cluster 2 : Palabras más frecuentes :
#  madr spain
#  spain
#  madr
#  madr madr
#  buen
#  fuenlabr madr
#  mostol madr
#  fuenlabr
#  dias
#  tod
#
# Cluster 3 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 4 : Palabras más frecuentes :
#  graci
#  …
#  much graci
#  much
#  graci segu
#  segu
#  tod
#  graci tod
#  brev devuelv
#  devuelv follow
#
# Cluster 5 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
# Cluster 6 : Palabras más frecuentes :
#  mas
#  …
#  much mas
#  par
#  much
#  madr
#  cad
#  si
#  mas …
#  mas bonit
#
# Cluster 7 : Palabras más frecuentes :
#  …
#  madr
#  hoy
#  tod
#  com
#  si
#  dia
#  buen
#  nuev
#  hac
#
# Cluster 8 : Palabras más frecuentes :
#  par
#  …
#  madr
#  tod
#  mejor
#  com
#  dia
#  hac
#  buen
#  hoy
#
# Cluster 9 : Palabras más frecuentes :
#  in
#  at
#  in madr
#  im at
#  im
#  madr
#  comun madr
#  comun
#  madr comun
#  madridbaraj mad
#
#
# Número de clusters: 11
# 0     12919
# 1      5761
# 8      1548
# 9      1231
# 3      1148
# 7      1042
# 4       703
# 6       668
# 5       648
# 2       590
# 10      105
# Name: Cluster_unibi_11, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  par
#  mas
#  via
#  madr
#  mejor
#  dia
#  per
#  hoy
#  nuev
#  hac
#
# Cluster 1 : Palabras más frecuentes :
#  …
#  buen
#  dias
#  buen dias
#  par
#  mas
#  hoy
#  madr
#  dia
#  nuestr
#
# Cluster 2 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 3 : Palabras más frecuentes :
#  com
#  …
#  par
#  hac
#  com …
#  si
#  hoy
#  dia
#  per
#  buen
#
# Cluster 4 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
# Cluster 5 : Palabras más frecuentes :
#  in
#  at
#  im at
#  im
#  in madr
#  madr
#  comun madr
#  comun
#  madr comun
#  madridbaraj mad
#
# Cluster 6 : Palabras más frecuentes :
#  graci
#  much graci
#  …
#  much
#  graci segu
#  segu
#  follow tuitutil
#  devuelv follow
#  brev devuelv
#  devuelv
#
# Cluster 7 : Palabras más frecuentes :
#  si
#  …
#  quier
#  per
#  ver si
#  si quier
#  ver
#  pued
#  par
#  mas
#
# Cluster 8 : Palabras más frecuentes :
#  madr
#  madr spain
#  spain
#  retir
#  in
#  españ
#  in madr
#  madr españ
#  retir madr
#  gran via
#
# Cluster 9 : Palabras más frecuentes :
#  tod
#  …
#  par
#  sab
#  tod …
#  dias
#  mas
#  par tod
#  per
#  buen
#
# Cluster 10 : Palabras más frecuentes :
#  unfollowers tuitutil
#  nuev seguidor
#  seguidor unfollowers
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  ey
#  facult cc
#  factor
#
#
# Número de clusters: 12
# 4     12229
# 6      4365
# 1      2177
# 5      1691
# 3      1372
# 10     1111
# 2       757
# 9       703
# 8       694
# 7       590
# 11      569
# 0       105
# Name: Cluster_unibi_12, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  unfollowers tuitutil
#  nuev seguidor
#  seguidor unfollowers
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  ey
#  facult cc
#  factor
#
# Cluster 1 : Palabras más frecuentes :
#  par
#  …
#  tod
#  mejor
#  madr
#  dia
#  hac
#  com
#  nuestr
#  list
#
# Cluster 2 : Palabras más frecuentes :
#  in
#  in madr
#  at
#  im at
#  im
#  madr
#  comun madr
#  comun
#  madr comun
#  madridbaraj mad
#
# Cluster 3 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  much mas
#  much
#  par
#  cad
#  pued
#  mas bonit
#  men
#
# Cluster 4 : Palabras más frecuentes :
#  madr
#  spain
#  via
#  tod
#  madr spain
#  mejor
#  españ
#  per
#  dia
#  sol
#
# Cluster 5 : Palabras más frecuentes :
#  com
#  hoy
#  …
#  dia
#  madr
#  tod
#  hac
#  hoy toc
#  toc
#  per
#
# Cluster 6 : Palabras más frecuentes :
#  …
#  madr
#  tod
#  dia
#  nuev
#  nuestr
#  mejor
#  hac
#  sol
#  vid
#
# Cluster 7 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 8 : Palabras más frecuentes :
#  graci
#  …
#  much graci
#  graci segu
#  much
#  segu
#  tod
#  graci tod
#  brev devuelv
#  devuelv follow
#
# Cluster 9 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
# Cluster 10 : Palabras más frecuentes :
#  si
#  …
#  quier
#  per
#  ver si
#  ver
#  pued
#  si quier
#  com
#  par
#
# Cluster 11 : Palabras más frecuentes :
#  buen dias
#  dias
#  buen
#  retir
#  viern
#  jardin buen
#  buen retir
#  retir jardin
#  jardin
#  retir madr
#
#
# Número de clusters: 13
# 0     12206
# 12     4527
# 11     2403
# 3      2168
# 1       839
# 8       795
# 10      733
# 9       703
# 6       613
# 5       590
# 2       564
# 4       117
# 7       105
# Name: Cluster_unibi_13, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  madr
#  mas
#  spain
#  tod
#  madr spain
#  via
#  per
#  sol
#  hoy
#  hac
#
# Cluster 1 : Palabras más frecuentes :
#  dia
#  …
#  hoy
#  madr
#  tierr
#  feliz dia
#  feliz
#  buen dia
#  dia tierr
#  par
#
# Cluster 2 : Palabras más frecuentes :
#  buen dias
#  dias
#  buen
#  retir
#  viern
#  jardin buen
#  buen retir
#  retir jardin
#  jardin
#  retir madr
#
# Cluster 3 : Palabras más frecuentes :
#  par
#  …
#  tod
#  mas
#  madr
#  hac
#  com
#  nuestr
#  par …
#  hoy
#
# Cluster 4 : Palabras más frecuentes :
#  gran via
#  via
#  gran
#  via madr
#  madr españ
#  españ
#  madr
#  madr gran
#  primark
#  phot
#
# Cluster 5 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 6 : Palabras más frecuentes :
#  quier
#  …
#  si
#  si quier
#  quier …
#  mas
#  com
#  per
#  ser
#  tod
#
# Cluster 7 : Palabras más frecuentes :
#  unfollowers tuitutil
#  nuev seguidor
#  seguidor unfollowers
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  ey
#  facult cc
#  factor
#
# Cluster 8 : Palabras más frecuentes :
#  mejor
#  …
#  list
#  madr
#  par
#  sal
#  tod
#  mas
#  sab
#  reserv
#
# Cluster 9 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
# Cluster 10 : Palabras más frecuentes :
#  in
#  at
#  in madr
#  im at
#  im
#  madr
#  comun madr
#  comun
#  madr comun
#  madridbaraj mad
#
# Cluster 11 : Palabras más frecuentes :
#  com
#  si
#  graci
#  …
#  tod
#  much
#  per
#  madr
#  hac
#  much graci
#
# Cluster 12 : Palabras más frecuentes :
#  …
#  madr
#  mas
#  tod
#  hoy
#  nuev
#  nuestr
#  hac
#  vid
#  sol
#
#
# Número de clusters: 14
# 0     12352
# 8      4972
# 1      2242
# 9      1218
# 2      1128
# 7       773
# 10      703
# 6       638
# 4       590
# 3       506
# 11      504
# 5       500
# 12      125
# 13      112
# Name: Cluster_unibi_14, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  par
#  mas
#  si
#  graci
#  nuev
#  mejor
#  per
#  dia
#  hoy
#  quier
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  …
#  in
#  in madr
#  españ
#  madr …
#  palaci
#  real
#  sol
#  real madr
#
# Cluster 2 : Palabras más frecuentes :
#  com
#  …
#  si
#  par
#  com …
#  per
#  hoy
#  dia
#  com si
#  quier
#
# Cluster 3 : Palabras más frecuentes :
#  at
#  im at
#  im
#  in
#  madr
#  in madr
#  comun madr
#  comun
#  madr comun
#  cosl
#
# Cluster 4 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 5 : Palabras más frecuentes :
#  buen dias
#  dias
#  buen
#  viern
#  feliz
#  hoy
#  …
#  felizviern
#  dias amig
#  dias feliz
#
# Cluster 6 : Palabras más frecuentes :
#  via
#  gran via
#  gran
#  via madr
#  madr
#  madr españ
#  españ
#  via youtub
#  via elmund
#  par
#
# Cluster 7 : Palabras más frecuentes :
#  hac
#  …
#  par
#  com
#  mas
#  si
#  com hac
#  par hac
#  tod
#  hac …
#
# Cluster 8 : Palabras más frecuentes :
#  …
#  par
#  mas
#  hoy
#  dia
#  si
#  nuestr
#  nuev
#  mejor
#  graci
#
# Cluster 9 : Palabras más frecuentes :
#  tod
#  …
#  par
#  graci
#  tod …
#  sab
#  graci tod
#  per
#  tod mund
#  par tod
#
# Cluster 10 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  tendenci madr
#  spain
#  madr
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
# Cluster 11 : Palabras más frecuentes :
#  madr spain
#  spain
#  madr
#  fuenlabr madr
#  madr madr
#  mostol madr
#  fuenlabr
#  mostol
#  dia
#  pabloalbor
#
# Cluster 12 : Palabras más frecuentes :
#  retir
#  retir madr
#  parqu retir
#  parqu
#  buen retir
#  jardin buen
#  retir jardin
#  jardin
#  madr
#  buen
#
# Cluster 13 : Palabras más frecuentes :
#  aeropuert adolf
#  suarez madridbaraj
#  madridbaraj
#  madridbaraj mad
#  adolf suarez
#  adolf
#  suarez
#  mad
#  mad aenaaeropuert
#  aenaaeropuert
#
#
# Número de clusters: 15
# 7     12494
# 10     4762
# 3      1297
# 11     1273
# 4      1114
# 13      967
# 9       755
# 6       755
# 0       628
# 2       590
# 14      561
# 12      367
# 8       360
# 5       335
# 1       105
# Name: Cluster_unibi_15, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  via
#  gran via
#  gran
#  via madr
#  madr
#  madr españ
#  españ
#  via youtub
#  via elmund
#  par
#
# Cluster 1 : Palabras más frecuentes :
#  unfollowers tuitutil
#  nuev seguidor
#  seguidor unfollowers
#  unfollowers
#  seguidor
#  tuitutil
#  nuev
#  ey
#  facult cc
#  factor
#
# Cluster 2 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 3 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  much mas
#  much
#  par
#  pued
#  cad
#  mas bonit
#  mejor
#
# Cluster 4 : Palabras más frecuentes :
#  com
#  …
#  par
#  si
#  madr
#  com …
#  tod
#  hoy
#  per
#  gust
#
# Cluster 5 : Palabras más frecuentes :
#  tendenci madr
#  ahor tendenci
#  tendenci
#  ahor
#  madr
#  ana
#  dasoul
#  visavis ahor
#  tiempodejueg
#  tiempodejueg ahor
#
# Cluster 6 : Palabras más frecuentes :
#  in
#  in madr
#  at
#  im at
#  im
#  madr
#  comun madr
#  comun
#  madr comun
#  aeropuert adolf
#
# Cluster 7 : Palabras más frecuentes :
#  madr
#  par
#  spain
#  tod
#  madr spain
#  mejor
#  sol
#  per
#  hoy
#  nuev
#
# Cluster 8 : Palabras más frecuentes :
#  sobr
#  …
#  rey juan
#  univers rey
#  rey
#  juan carl
#  juan
#  univers
#  carl
#  par
#
# Cluster 9 : Palabras más frecuentes :
#  hac
#  …
#  par
#  com
#  com hac
#  mas
#  tod
#  par hac
#  falt
#  si
#
# Cluster 10 : Palabras más frecuentes :
#  …
#  par
#  madr
#  tod
#  hoy
#  nuev
#  nuestr
#  mejor
#  noch
#  sab
#
# Cluster 11 : Palabras más frecuentes :
#  graci
#  dia
#  …
#  much graci
#  tod
#  much
#  hoy
#  graci segu
#  madr
#  segu
#
# Cluster 12 : Palabras más frecuentes :
#  tendenci spain
#  ahor tendenci
#  tendenci
#  ahor
#  spain
#  sv ahor
#  visavis ahor
#  tiempodejueg ahor
#  tiempodejueg
#  axe
#
# Cluster 13 : Palabras más frecuentes :
#  si
#  …
#  quier
#  per
#  ver si
#  si quier
#  pued
#  ver
#  par
#  ser
#
# Cluster 14 : Palabras más frecuentes :
#  buen dias
#  dias
#  buen
#  retir
#  viern
#  jardin buen
#  buen retir
#  retir jardin
#  jardin
#  retir madr

# %% [markdown]
# * ### K-means con unigramas, bigramas y trigramas

# %%
# Convertimos la lista en la matriz Tf-idf
vectorizer_unibitri = TfidfVectorizer(
                max_df = 0.95,
                min_df = 0.00005,
                max_features = 30000,
                analyzer = 'word',
                tokenizer = tokenize,
                lowercase = True,
                use_idf = True,
                stop_words = spanish_stopwords,
                ngram_range=(1,3))
mx_tfidf_unibitri = vectorizer_unibitri.fit_transform(tweets_text)

# %%
mx_tfidf_unibitri.shape
# Out:
# (26363, 30000)

# %%
# Realización del clustering con k-means
kmeans_function(16, mx_tfidf_unibitri, tweets, vectorizer_unibitri, "unibitri", 3333)
# Out:
# Número de clusters: 5
# 1    17647
# 0     6642
# 3      791
# 2      696
# 4      587
# Name: Cluster_unibitri_5, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  …
#  par
#  madr
#  mas
#  tod
#  hoy
#  com
#  dia
#  si
#  nuestr
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  par
#  buen
#  mas
#  com
#  si
#  tod
#  spain
#  dias
#  via
#
# Cluster 2 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  ahor tendenci spain
#  tendenci madr
#  ahor tendenci madr
#  spain
#  madr
#  visavis ahor
#
# Cluster 3 : Palabras más frecuentes :
#  in
#  in madr
#  madr
#  at
#  im at
#  im
#  comun madr
#  comun
#  madr comun
#  madr comun madr
#
# Cluster 4 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
#
# Número de clusters: 6
# 0    20706
# 1     2400
# 4     1470
# 5      696
# 3      587
# 2      504
# Name: Cluster_unibitri_6, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  …
#  madr
#  mas
#  com
#  si
#  in
#  hoy
#  graci
#  spain
#  dia
#
# Cluster 1 : Palabras más frecuentes :
#  par
#  …
#  tuitutil
#  nuev
#  seguidor
#  nuev seguidor
#  nuev seguidor unfollowers
#  seguidor unfollowers
#  unfollowers
#  unfollowers tuitutil
#
# Cluster 2 : Palabras más frecuentes :
#  dias
#  buen dias
#  buen
#  viern
#  feliz
#  hoy
#  …
#  felizviern
#  dias amig
#  buen dias amig
#
# Cluster 3 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 4 : Palabras más frecuentes :
#  tod
#  …
#  retir
#  madr
#  retir madr
#  par
#  graci
#  parqu retir
#  buen
#  tod …
#
# Cluster 5 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  ahor tendenci spain
#  tendenci madr
#  ahor tendenci madr
#  spain
#  madr
#  visavis ahor
#
#
# Número de clusters: 7
# 0    15068
# 6     5635
# 2     2415
# 4     1459
# 5      696
# 1      587
# 3      503
# Name: Cluster_unibitri_7, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  madr
#  mas
#  com
#  si
#  tod
#  graci
#  via
#  per
#  nuev
#  mejor
#
# Cluster 1 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 2 : Palabras más frecuentes :
#  par
#  …
#  tod
#  mas
#  mejor
#  com
#  hac
#  madr
#  dia
#  hoy
#
# Cluster 3 : Palabras más frecuentes :
#  dias
#  buen dias
#  buen
#  viern
#  feliz
#  hoy
#  …
#  felizviern
#  buen dias amig
#  dias amig
#
# Cluster 4 : Palabras más frecuentes :
#  madr
#  in
#  madr spain
#  in madr
#  spain
#  at
#  im at
#  im
#  comun madr
#  comun
#
# Cluster 5 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  ahor tendenci spain
#  tendenci madr
#  ahor tendenci madr
#  spain
#  madr
#  visavis ahor
#
# Cluster 6 : Palabras más frecuentes :
#  …
#  madr
#  mas
#  tod
#  hoy
#  com
#  si
#  dia
#  graci
#  nuestr
#
#
# Número de clusters: 8
# 6    15042
# 7     5519
# 1     2353
# 0     1263
# 4      800
# 2      694
# 5      587
# 3      105
# Name: Cluster_unibitri_8, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  com
#  …
#  par
#  si
#  per
#  hac
#  tod
#  com …
#  madr
#  hoy
#
# Cluster 1 : Palabras más frecuentes :
#  par
#  …
#  tod
#  madr
#  mas
#  mejor
#  dia
#  hoy
#  buen
#  hac
#
# Cluster 2 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  ahor tendenci spain
#  tendenci madr
#  ahor tendenci madr
#  spain
#  madr
#  visavis ahor
#
# Cluster 3 : Palabras más frecuentes :
#  seguidor unfollowers
#  unfollowers
#  unfollowers tuitutil
#  nuev seguidor unfollowers
#  nuev seguidor
#  seguidor unfollowers tuitutil
#  seguidor
#  tuitutil
#  nuev
#  eugelopezmaur
#
# Cluster 4 : Palabras más frecuentes :
#  in
#  in madr
#  madr
#  at
#  im at
#  im
#  comun madr
#  comun
#  in madr comun
#  madr comun madr
#
# Cluster 5 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 6 : Palabras más frecuentes :
#  madr
#  buen
#  mas
#  spain
#  si
#  dias
#  tod
#  graci
#  via
#  madr spain
#
# Cluster 7 : Palabras más frecuentes :
#  …
#  madr
#  mas
#  tod
#  hoy
#  dia
#  si
#  graci
#  buen
#  nuestr
#
#
# Número de clusters: 9
# 2    15903
# 7     6093
# 6      884
# 4      816
# 1      778
# 5      696
# 3      587
# 8      501
# 0      105
# Name: Cluster_unibitri_9, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  seguidor unfollowers
#  unfollowers
#  unfollowers tuitutil
#  nuev seguidor unfollowers
#  nuev seguidor
#  seguidor unfollowers tuitutil
#  seguidor
#  tuitutil
#  nuev
#  eugelopezmaur
#
# Cluster 1 : Palabras más frecuentes :
#  in
#  in madr
#  at
#  madr
#  im at
#  im
#  comun madr
#  comun
#  in madr comun
#  madr comun
#
# Cluster 2 : Palabras más frecuentes :
#  par
#  madr
#  mas
#  com
#  si
#  tod
#  graci
#  via
#  mejor
#  per
#
# Cluster 3 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 4 : Palabras más frecuentes :
#  madr
#  madr spain
#  spain
#  retir
#  retir madr
#  gran via
#  españ
#  madr españ
#  via madr
#  gran via madr
#
# Cluster 5 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  ahor tendenci spain
#  tendenci madr
#  ahor tendenci madr
#  spain
#  madr
#  visavis ahor
#
# Cluster 6 : Palabras más frecuentes :
#  ser
#  gan
#  …
#  par
#  pued
#  pued ser
#  mas
#  si
#  per
#  quier
#
# Cluster 7 : Palabras más frecuentes :
#  …
#  par
#  tod
#  madr
#  mas
#  hoy
#  com
#  dia
#  si
#  nuestr
#
# Cluster 8 : Palabras más frecuentes :
#  dias
#  buen dias
#  buen
#  viern
#  feliz
#  hoy
#  …
#  felizviern
#  dias amig
#  buen dias amig
#
#
# Número de clusters: 10
# 1    13694
# 2     5016
# 8     2181
# 6     1249
# 7      807
# 3      777
# 4      772
# 5      694
# 9      587
# 0      586
# Name: Cluster_unibitri_10, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  buen dias
#  dias
#  buen
#  unfollowers
#  unfollowers tuitutil
#  seguidor unfollowers
#  nuev seguidor unfollowers
#  nuev seguidor
#  seguidor unfollowers tuitutil
#  seguidor
#
# Cluster 1 : Palabras más frecuentes :
#  madr
#  mas
#  com
#  si
#  graci
#  via
#  dia
#  mejor
#  quier
#  hoy
#
# Cluster 2 : Palabras más frecuentes :
#  …
#  madr
#  mas
#  hoy
#  com
#  dia
#  si
#  nuestr
#  mejor
#  hac
#
# Cluster 3 : Palabras más frecuentes :
#  per
#  …
#  si
#  com
#  tod
#  per si
#  per …
#  mas
#  par
#  ser
#
# Cluster 4 : Palabras más frecuentes :
#  in
#  in madr
#  at
#  madr
#  im at
#  im
#  comun madr
#  comun
#  madr comun madr
#  madr comun
#
# Cluster 5 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  ahor tendenci spain
#  tendenci madr
#  ahor tendenci madr
#  spain
#  madr
#  visavis ahor
#
# Cluster 6 : Palabras más frecuentes :
#  tod
#  …
#  graci
#  tod …
#  par
#  sab
#  graci tod
#  mas
#  com
#  si
#
# Cluster 7 : Palabras más frecuentes :
#  madr
#  madr spain
#  spain
#  retir
#  retir madr
#  gran via
#  via madr
#  gran via madr
#  españ
#  madr españ
#
# Cluster 8 : Palabras más frecuentes :
#  par
#  …
#  mejor
#  mas
#  com
#  hac
#  hoy
#  dia
#  madr
#  nuestr
#
# Cluster 9 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
#
# Número de clusters: 11
# 1     16462
# 5      3174
# 2      1381
# 4      1206
# 7      1150
# 6       877
# 8       724
# 3       587
# 10      363
# 9       334
# 0       105
# Name: Cluster_unibitri_11, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  seguidor unfollowers
#  unfollowers
#  unfollowers tuitutil
#  nuev seguidor unfollowers
#  nuev seguidor
#  seguidor unfollowers tuitutil
#  seguidor
#  tuitutil
#  nuev
#  eugelopezmaur
#
# Cluster 1 : Palabras más frecuentes :
#  …
#  madr
#  buen
#  tod
#  com
#  graci
#  dias
#  mejor
#  hac
#  per
#
# Cluster 2 : Palabras más frecuentes :
#  madr
#  in
#  in madr
#  madr spain
#  at
#  spain
#  im at
#  im
#  comun madr
#  comun
#
# Cluster 3 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 4 : Palabras más frecuentes :
#  hoy
#  pas
#  …
#  hoy toc
#  toc
#  buen
#  com
#  dias
#  madr
#  tod
#
# Cluster 5 : Palabras más frecuentes :
#  par
#  mas
#  …
#  tod
#  madr
#  mejor
#  hac
#  much
#  com
#  nuestr
#
# Cluster 6 : Palabras más frecuentes :
#  dia
#  …
#  hoy
#  buen
#  feliz dia
#  feliz
#  tierr
#  buen dia
#  par
#  madr
#
# Cluster 7 : Palabras más frecuentes :
#  si
#  …
#  retir
#  quier
#  buen
#  per
#  com
#  jardin buen retir
#  jardin buen
#  buen retir
#
# Cluster 8 : Palabras más frecuentes :
#  sol
#  madr
#  gran via
#  via
#  gran
#  gran via madr
#  via madr
#  españ
#  via madr españ
#  sol madr
#
# Cluster 9 : Palabras más frecuentes :
#  tendenci madr
#  ahor tendenci madr
#  ahor tendenci
#  tendenci
#  ahor
#  madr
#  ana
#  dasoul
#  coron
#  valverd
#
# Cluster 10 : Palabras más frecuentes :
#  ahor tendenci spain
#  tendenci spain
#  ahor tendenci
#  tendenci
#  ahor
#  spain
#  axe
#  jorg
#  txelui
#  sv ahor
#
#
# Número de clusters: 12
# 0     11648
# 5      4359
# 1      2298
# 6      2235
# 9      2130
# 4       695
# 3       653
# 2       653
# 7       587
# 10      509
# 8       491
# 11      105
# Name: Cluster_unibitri_12, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  si
#  graci
#  tod
#  mejor
#  per
#  quier
#  hoy
#  dia
#  hac
#  buen
#
# Cluster 1 : Palabras más frecuentes :
#  par
#  …
#  tod
#  hac
#  mas
#  com
#  hoy
#  dia
#  mejor
#  nuestr
#
# Cluster 2 : Palabras más frecuentes :
#  in
#  at
#  im at
#  im
#  in madr
#  madr
#  comun madr
#  comun
#  in madr comun
#  madr comun madr
#
# Cluster 3 : Palabras más frecuentes :
#  via
#  gran via
#  gran
#  via madr
#  gran via madr
#  via madr españ
#  madr
#  madr españ
#  españ
#  via youtub
#
# Cluster 4 : Palabras más frecuentes :
#  ahor tendenci
#  tendenci
#  ahor
#  tendenci spain
#  ahor tendenci spain
#  tendenci madr
#  ahor tendenci madr
#  spain
#  madr
#  visavis ahor
#
# Cluster 5 : Palabras más frecuentes :
#  …
#  tod
#  hoy
#  si
#  dia
#  graci
#  nuestr
#  hac
#  nuev
#  mejor
#
# Cluster 6 : Palabras más frecuentes :
#  mas
#  com
#  …
#  si
#  tod
#  much
#  hac
#  per
#  dia
#  quier
#
# Cluster 7 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 8 : Palabras más frecuentes :
#  dias
#  buen dias
#  buen
#  viern
#  feliz
#  hoy
#  …
#  felizviern
#  buen dias amig
#  dias amig
#
# Cluster 9 : Palabras más frecuentes :
#  madr
#  …
#  retir
#  in
#  in madr
#  retir madr
#  madr …
#  españ
#  sol
#  palaci
#
# Cluster 10 : Palabras más frecuentes :
#  madr spain
#  spain
#  madr
#  madr madr spain
#  fuenlabr madr spain
#  fuenlabr madr
#  mostol madr spain
#  in madr spain
#  mostol madr
#  fuenlabr
#
# Cluster 11 : Palabras más frecuentes :
#  seguidor unfollowers
#  unfollowers
#  unfollowers tuitutil
#  nuev seguidor unfollowers
#  nuev seguidor
#  seguidor unfollowers tuitutil
#  seguidor
#  tuitutil
#  nuev
#  eugelopezmaur
#
#
# Número de clusters: 13
# 0     13715
# 9      4818
# 11     1782
# 4      1401
# 8       800
# 12      784
# 7       767
# 2       587
# 1       496
# 6       412
# 10      363
# 5       333
# 3       105
# Name: Cluster_unibitri_13, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  par
#  madr
#  com
#  graci
#  tod
#  via
#  mejor
#  per
#  hac
#  nuev
#
# Cluster 1 : Palabras más frecuentes :
#  dias
#  buen dias
#  buen
#  viern
#  feliz
#  hoy
#  …
#  felizviern
#  dias amig
#  buen dias amig
#
# Cluster 2 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 3 : Palabras más frecuentes :
#  seguidor unfollowers
#  unfollowers
#  unfollowers tuitutil
#  nuev seguidor unfollowers
#  nuev seguidor
#  seguidor unfollowers tuitutil
#  seguidor
#  tuitutil
#  nuev
#  eugelopezmaur
#
# Cluster 4 : Palabras más frecuentes :
#  mas
#  …
#  par
#  much
#  much mas
#  madr
#  cad
#  pued
#  mas …
#  mas bonit
#
# Cluster 5 : Palabras más frecuentes :
#  ahor tendenci madr
#  tendenci madr
#  ahor tendenci
#  tendenci
#  ahor
#  madr
#  dasoul
#  coron
#  ana
#  valverd
#
# Cluster 6 : Palabras más frecuentes :
#  cas
#  puert
#  sol madr
#  puert sol
#  sol
#  puert sol madr
#  madr
#  …
#  vuelv
#  cas camp
#
# Cluster 7 : Palabras más frecuentes :
#  in
#  in madr
#  at
#  madr
#  im at
#  im
#  comun madr
#  comun
#  in madr comun
#  madr comun
#
# Cluster 8 : Palabras más frecuentes :
#  madr
#  madr spain
#  spain
#  retir
#  retir madr
#  gran via
#  via madr
#  gran via madr
#  españ
#  madr españ
#
# Cluster 9 : Palabras más frecuentes :
#  …
#  par
#  tod
#  madr
#  com
#  nuestr
#  dia
#  graci
#  nuev
#  hac
#
# Cluster 10 : Palabras más frecuentes :
#  ahor tendenci spain
#  tendenci spain
#  ahor tendenci
#  tendenci
#  ahor
#  spain
#  axe
#  jorg
#  txelui
#  sv ahor
#
# Cluster 11 : Palabras más frecuentes :
#  si
#  hoy
#  …
#  dia
#  com
#  par
#  quier
#  per
#  tod
#  hac
#
# Cluster 12 : Palabras más frecuentes :
#  esper
#  felic
#  disfrut
#  …
#  par
#  tod
#  much
#  mejor
#  list
#  madr
#
#
# Número de clusters: 14
# 11    11741
# 1      4366
# 5      2916
# 2      1290
# 4      1112
# 7      1067
# 6       843
# 13      745
# 8       628
# 3       587
# 10      363
# 9       333
# 0       267
# 12      105
# Name: Cluster_unibitri_14, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  cre
#  …
#  mas
#  pued
#  par
#  si
#  per
#  tod
#  nunc
#  cre si
#
# Cluster 1 : Palabras más frecuentes :
#  …
#  buen
#  dias
#  buen dias
#  tod
#  madr
#  graci
#  com
#  noch
#  mejor
#
# Cluster 2 : Palabras más frecuentes :
#  madr
#  in
#  in madr
#  at
#  madr spain
#  im at
#  im
#  spain
#  comun madr
#  comun
#
# Cluster 3 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 4 : Palabras más frecuentes :
#  hoy
#  pas
#  …
#  hoy toc
#  toc
#  com
#  madr
#  par
#  tod
#  aqu
#
# Cluster 5 : Palabras más frecuentes :
#  par
#  mas
#  …
#  madr
#  tod
#  mejor
#  much
#  com
#  nuestr
#  sab
#
# Cluster 6 : Palabras más frecuentes :
#  dia
#  …
#  hoy
#  feliz dia
#  buen
#  tierr
#  feliz
#  buen dia
#  madr
#  par
#
# Cluster 7 : Palabras más frecuentes :
#  si
#  …
#  retir
#  quier
#  jardin buen retir
#  jardin buen
#  buen retir
#  retir jardin
#  retir jardin buen
#  jardin
#
# Cluster 8 : Palabras más frecuentes :
#  sol
#  gran via
#  madr
#  via
#  gran
#  gran via madr
#  via madr
#  via madr españ
#  sol madr
#  puert sol
#
# Cluster 9 : Palabras más frecuentes :
#  ahor tendenci madr
#  tendenci madr
#  ahor tendenci
#  tendenci
#  ahor
#  madr
#  dasoul
#  coron
#  ana
#  valverd
#
# Cluster 10 : Palabras más frecuentes :
#  ahor tendenci spain
#  tendenci spain
#  ahor tendenci
#  tendenci
#  ahor
#  spain
#  axe
#  jorg
#  txelui
#  sv ahor
#
# Cluster 11 : Palabras más frecuentes :
#  madr
#  com
#  graci
#  tod
#  via
#  mejor
#  per
#  nuev
#  quier
#  sab
#
# Cluster 12 : Palabras más frecuentes :
#  seguidor unfollowers
#  unfollowers
#  unfollowers tuitutil
#  nuev seguidor unfollowers
#  nuev seguidor
#  seguidor unfollowers tuitutil
#  seguidor
#  tuitutil
#  nuev
#  eugelopezmaur
#
# Cluster 13 : Palabras más frecuentes :
#  hac
#  …
#  par
#  com
#  mas
#  si
#  tod
#  com hac
#  par hac
#  per
#
#
# Número de clusters: 15
# 11    11268
# 1      4300
# 5      2812
# 2      1283
# 4      1103
# 7      1050
# 6       837
# 13      737
# 8       676
# 14      642
# 3       587
# 10      363
# 9       333
# 0       267
# 12      105
# Name: Cluster_unibitri_15, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  cre
#  …
#  mas
#  pued
#  par
#  si
#  per
#  tod
#  nunc
#  cre si
#
# Cluster 1 : Palabras más frecuentes :
#  …
#  buen
#  dias
#  buen dias
#  tod
#  madr
#  graci
#  com
#  noch
#  mejor
#
# Cluster 2 : Palabras más frecuentes :
#  madr
#  in
#  in madr
#  at
#  madr spain
#  im at
#  im
#  spain
#  comun madr
#  comun
#
# Cluster 3 : Palabras más frecuentes :
#  autop autov
#  autov
#  autop
#  dgtmadr dgt
#  dgtmadr
#  dgt
#  retencion nivel
#  retencion
#  nivel
#  pk
#
# Cluster 4 : Palabras más frecuentes :
#  hoy
#  pas
#  …
#  hoy toc
#  toc
#  com
#  madr
#  par
#  tod
#  aqu
#
# Cluster 5 : Palabras más frecuentes :
#  par
#  mas
#  …
#  tod
#  madr
#  mejor
#  much
#  com
#  nuestr
#  ser
#
# Cluster 6 : Palabras más frecuentes :
#  dia
#  …
#  hoy
#  feliz dia
#  buen
#  tierr
#  feliz
#  buen dia
#  madr
#  par
#
# Cluster 7 : Palabras más frecuentes :
#  si
#  …
#  retir
#  quier
#  jardin buen retir
#  jardin buen
#  buen retir
#  retir jardin
#  retir jardin buen
#  jardin
#
# Cluster 8 : Palabras más frecuentes :
#  sol
#  madr
#  españ
#  madr españ
#  sol madr
#  via madr españ
#  gran via madr
#  via madr
#  puert sol
#  gran via
#
# Cluster 9 : Palabras más frecuentes :
#  ahor tendenci madr
#  tendenci madr
#  ahor tendenci
#  tendenci
#  ahor
#  madr
#  dasoul
#  coron
#  ana
#  valverd
#
# Cluster 10 : Palabras más frecuentes :
#  ahor tendenci spain
#  tendenci spain
#  ahor tendenci
#  tendenci
#  ahor
#  spain
#  axe
#  jorg
#  txelui
#  sv ahor
#
# Cluster 11 : Palabras más frecuentes :
#  madr
#  com
#  graci
#  tod
#  mejor
#  per
#  quier
#  nuev
#  sab
#  tien
#
# Cluster 12 : Palabras más frecuentes :
#  seguidor unfollowers
#  unfollowers
#  unfollowers tuitutil
#  nuev seguidor unfollowers
#  nuev seguidor
#  seguidor unfollowers tuitutil
#  seguidor
#  tuitutil
#  nuev
#  eugelopezmaur
#
# Cluster 13 : Palabras más frecuentes :
#  hac
#  …
#  par
#  com
#  mas
#  si
#  tod
#  com hac
#  par hac
#  per
#
# Cluster 14 : Palabras más frecuentes :
#  via
#  gran via
#  gran
#  via youtub
#  par
#  via elmund
#  elmund
#  madr
#  youtub
#  elpais

# %% [markdown]
# * ### Asignación de temas/topics

# %%
# Por defecto, asignamos el tema 'otros'
tweets['Topic'] = 'otros'

# %%
# Asignación de tema 'sitios-madrid'
tweets.loc[(tweets["Cluster_unig_8"] == 4) & (tweets["Cluster_unig_11"] == 7) & 
           (tweets["Cluster_unig_12"] == 7) & (tweets["Cluster_unig_13"] == 1) & 
           (tweets["Cluster_unig_15"] == 12) & (tweets["Cluster_unig2_10"] == 5) &
           (tweets["Cluster_unig2_11"] == 8) & (tweets["Cluster_unig2_12"] == 8) &
           (tweets["Cluster_unig2_13"] == 5) & (tweets["Cluster_unig2_14"] == 8) &
           (tweets["Cluster_unig2_15"] == 4) & (tweets["Cluster_unibi_11"] == 8) & 
           (tweets["Cluster_unibi_14"] == 1) & (tweets["Cluster_unibitri_12"] == 9) &
           (tweets["Cluster_unibitri_13"] == 6),'Topic'] = 'sitios-madrid'

# %%
tweets['Topic'].value_counts()
# Out:
# otros            26307
# sitios-madrid       56
# Name: Topic, dtype: int64

# %%
# Se incluye un nuevo subconjunto a 'sitios-madrid', que teóricamente incluye pueblos de la Comunidad
tweets.loc[(tweets["Cluster_unig_14"] == 4) | (tweets["Cluster_unig_15"] == 0) | 
           (tweets["Cluster_unibi_10"] == 2) | (tweets["Cluster_unibitri_12"] == 10),
           'Topic'] = 'sitios-madrid'

# %%
tweets['Topic'].value_counts()
# Out:
# otros            25269
# sitios-madrid     1094
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'sitios-madrid',["content"]].head()
# Out:
#                                                 content
# 2781  I'm at @Facilisimo.com in Villaviciosa de Odón...
# 3828  I'm at AC Hotel La Finca in Pozuelo de Alarcón...
# 4824  ¡La cocina es el corazón de la casa! Refórmala...
# 5845                   I'm at Madrid in Madrid, España
# 6208                       I'm at Viva Gym embajadores

# %%
# Asignación de tema 'buenos-dias'
tweets.loc[(tweets["Cluster_unig_7"] == 1) & (tweets["Cluster_unig_11"] == 5) & 
           (tweets["Cluster_unig_13"] == 8) & (tweets["Cluster_unig_14"] == 13) & 
           (tweets["Cluster_unig_15"] == 10) & (tweets["Cluster_unig2_6"] == 5) &
           (tweets["Cluster_unig2_8"] == 1) & (tweets["Cluster_unig2_9"] == 5) &
           (tweets["Cluster_unig2_10"] == 8) & (tweets["Cluster_unig2_11"] == 10) &
           (tweets["Cluster_unig2_12"] == 10) & (tweets["Cluster_unig2_14"] == 10) &
           (tweets["Cluster_unig2_15"] == 8) & (tweets["Cluster_unibi_7"] == 2) & 
           (tweets["Cluster_unibi_9"] == 7) & (tweets["Cluster_unibi_12"] == 11) & 
           (tweets["Cluster_unibi_13"] == 2) & (tweets["Cluster_unibi_14"] == 5) & 
           (tweets["Cluster_unibi_15"] == 14) & (tweets["Cluster_unibitri_6"] == 2) &
           (tweets["Cluster_unibitri_7"] == 3) & (tweets["Cluster_unibitri_9"] == 8) &
           (tweets["Cluster_unibitri_12"] == 8) & (tweets["Cluster_unibitri_13"] == 1),
           'Topic'] = 'buenos-dias'

# %%
tweets['Topic'].value_counts()
# Out:
# otros            24865
# sitios-madrid     1091
# buenos-dias        407
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'buenos-dias',["content"]].head()
# Out:
#                                                 content
# 413   @kardiez2000 Buenos días, no sé si conocías la...
# 687   @margarita_5239 Buenos días cielete y feliz fi...
# 699   @maricarmengar15 @Pedramuz @Mariquinaperez @ma...
# 845   @raulitopro11 buenos dias  Raul feliz Viernes ...
# 1066  @Vermutinn jajajajjaja Se lo merecía,  es insu...

# %%
# Asignación de tema 'retiro'
tweets.loc[(tweets["Cluster_unibi_14"] == 12) & (tweets["Cluster_unibitri_9"] == 4) & 
           (tweets["Cluster_unibitri_10"] == 7) & (tweets["Cluster_unibitri_11"] == 7) & 
           (tweets["Cluster_unibitri_14"] == 7) & (tweets["Cluster_unibitri_15"] == 7), 
           'Topic'] = 'retiro'

# %%
tweets['Topic'].value_counts()
# Out:
# otros            24805
# sitios-madrid     1090
# buenos-dias        407
# retiro              61
# Name: Topic, dtype: int64

# %%
# Es muy restrictivo, cuando había un grupo claro en Cluster_unibi_14. Usaremos solo ese
tweets.loc[(tweets["Cluster_unibi_14"] == 12), 'Topic'] = 'retiro'

# %%
tweets['Topic'].value_counts()
# Out:
# otros            24743
# sitios-madrid     1088
# buenos-dias        407
# retiro             125
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'retiro',["content"]].head()
# Out:
#                                                  content
# 9832   "Claro que lo bueno cuesta que no lo ganas si ...
# 10039  ayer eramos rookies hoy somos all-stars @ Parq...
# 10330  De Jardines del Buen Retiro \n#mrcade #reproch...
# 10438  #Beerlover #Instabeer - #Madrid, #Spain. 🇪🇸 @ ...
# 10500  #TBT Mayo 15. Palacio de Cristal en el Parque ...

# %%
# Asignación de tema 'gran-via'
tweets.loc[(tweets["Cluster_unibi_13"] == 4) & (tweets["Cluster_unibi_14"] == 6) &
           (tweets["Cluster_unibi_15"] == 0) & (tweets["Cluster_unibitri_12"] == 3), 'Topic'] = 'gran-via'

# %%
tweets['Topic'].value_counts()
# Out:
# otros            24633
# sitios-madrid     1083
# buenos-dias        407
# retiro             125
# gran-via           115
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'gran-via',["content"]].head()
# Out:
#                                                 content
# 72         Shredded Chicken Salpicón  via @Leslie_Limon
# 728                                          vía @giphy
# 1719  Alimentaria celebra en el recinto Gran Vía de ...
# 3717  Ayer me compré de oferta estos 3 libros en las...
# 5531                                Vía @LaCastaSusana

# %%
# Asignación de tema 'gracias'
tweets.loc[(tweets["Cluster_unig_14"] == 11) & (tweets["Cluster_unig2_9"] == 6) &
           (tweets["Cluster_unig2_14"] == 12) & (tweets["Cluster_unibi_13"] == 11) & 
           (tweets["Cluster_unibi_15"] == 11), 'Topic'] = 'gracias'

# %%
tweets['Topic'].value_counts()
# Out:
# otros            24577
# sitios-madrid     1083
# buenos-dias        407
# retiro             125
# gran-via           115
# gracias             56
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'gracias',["content"]].head()
# Out:
#                                                 content
# 233   @GlamourSpain correspondiente porque no lo he ...
# 270   Y se cumple un año de #SeisHermanas muchas gra...
# 449   Mi principe, muchas gracias, siempre apoyando,...
# 643   @Tri_finisher @totibest Muchas gracias por com...
# 1287  @stephipugliese @BrunoVD @FerRubioA @soyAlicia...

# %%
# Asignación de tema 'followers'
tweets.loc[(tweets["Cluster_unibi_5"] == 2) & (tweets["Cluster_unibi_8"] == 0) & 
           (tweets["Cluster_unibi_10"] == 0) & (tweets["Cluster_unibi_11"] == 10) & 
           (tweets["Cluster_unibi_12"] == 0) & (tweets["Cluster_unibi_13"] == 7) & 
           (tweets["Cluster_unibi_15"] == 1) & (tweets["Cluster_unibitri_6"] == 1) & 
           (tweets["Cluster_unibitri_8"] == 3) & (tweets["Cluster_unibitri_9"] == 0) & 
           (tweets["Cluster_unibitri_10"] == 0) & (tweets["Cluster_unibitri_11"] == 0) & 
           (tweets["Cluster_unibitri_12"] == 11) & (tweets["Cluster_unibitri_9"] == 0) & 
           (tweets["Cluster_unibitri_13"] == 3) & (tweets["Cluster_unibitri_14"] == 12) & 
           (tweets["Cluster_unibitri_15"] == 12), 'Topic'] = 'followers'

# %%
tweets['Topic'].value_counts()
# Out:
# otros            24472
# sitios-madrid     1083
# buenos-dias        407
# retiro             125
# gran-via           115
# followers          105
# gracias             56
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'followers',["content"]].head()
# Out:
#                                                 content
# 418   Nuevos seguidores: 2, unfollowers: 1 (14:45) #...
# 562   Nuevos seguidores: 1, unfollowers: 1 (13:37) #...
# 1003  Nuevos seguidores: 1, unfollowers: 0 (11:20) #...
# 1116  Nuevos seguidores: 0, unfollowers: 1 (11:19) #...
# 1170  Nuevos seguidores: 1, unfollowers: 0 (11:19) #...

# %%
# Asignación de tema 'tendencias-twitter'
tweets.loc[(tweets["Cluster_unig_5"] == 2) & (tweets["Cluster_unig_6"] == 4) & 
           (tweets["Cluster_unig_7"] == 5) & (tweets["Cluster_unig_8"] == 7) & 
           (tweets["Cluster_unig_9"] == 8) & (tweets["Cluster_unig_10"] == 9) &
           (tweets["Cluster_unig_11"] == 8) & (tweets["Cluster_unig_12"] == 10) &
           (tweets["Cluster_unig_13"] == 9) & (tweets["Cluster_unig_14"] == 12) &
           (tweets["Cluster_unig_15"] == 4) &  (tweets["Cluster_unig2_5"] == 4) &
           (tweets["Cluster_unig2_7"] == 5) & (tweets["Cluster_unig2_8"] == 5) &
           (tweets["Cluster_unig2_9"] == 1) & (tweets["Cluster_unig2_10"] == 7) &
           (tweets["Cluster_unig2_11"] == 4) & (tweets["Cluster_unig2_12"] == 4) &
           (tweets["Cluster_unig2_13"] == 7) & (tweets["Cluster_unig2_14"] == 4) &
           (tweets["Cluster_unig2_15"] == 6),
           'Topic'] = 'tendencias-twitter'

# %%
tweets['Topic'].value_counts()
# Out:
# otros                 23762
# sitios-madrid          1083
# tendencias-twitter      710
# buenos-dias             407
# retiro                  125
# gran-via                115
# followers               105
# gracias                  56
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'tendencias-twitter',["content"]].head()
# Out:
#                                                 content
# 6        'nicholson' es ahora una tendencia en #Madrid
# 6992                8 Tendencias de Email marketing  |
# 7734                            Seguro de Vida; ahora!
# 8896                8 Tendencias de Email marketing  |
# 9693  #cuentamenoche es ahora una tendencia en #Madrid

# %%
# Asignación de tema 'discoteca'
tweets.loc[(tweets["Cluster_unig_9"] == 7) & (tweets["Cluster_unig_11"] == 0) &
           (tweets["Cluster_unig2_6"] == 2) & (tweets["Cluster_unig2_8"] == 0) &
           (tweets["Cluster_unig2_10"] == 3) & (tweets["Cluster_unig2_12"] == 11) &
           (tweets["Cluster_unig2_13"] == 4) & (tweets["Cluster_unig2_14"] == 11) &
           (tweets["Cluster_unig2_15"] == 13),'Topic'] = 'discoteca'

# %%
tweets['Topic'].value_counts()
# Out:
# otros                 23591
# sitios-madrid          1083
# tendencias-twitter      710
# buenos-dias             407
# discoteca               171
# retiro                  125
# gran-via                115
# followers               105
# gracias                  56
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'discoteca',["content"]].head()
# Out:
#                                                content
# 327  Listas #show meclub! Te esperamos con la mejor...
# 328  Zoe-  RESERVADOS y Listas! - SÁBADO- 100 eu re...
# 332  No te pierdas este finde en en Riviera Madrid ...
# 347  Este sabado la mejor fiesta con mejor espectac...
# 360  Este sabado SHOW ME' en La Tartufo!! TRAP, #FU...

# %%
# Asignación de tema 'trafico' (como aparece en todos, cogeremos el primero)
tweets.loc[(tweets["Cluster_unig_5"] == 1),'Topic'] = 'trafico'

# %%
tweets['Topic'].value_counts()
# Out:
# otros                 22992
# sitios-madrid          1083
# tendencias-twitter      710
# trafico                 599
# buenos-dias             407
# discoteca               171
# retiro                  125
# gran-via                115
# followers               105
# gracias                  56
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'trafico',["content"]].head()
# Out:
#                                                 content
# 2549  #RETENCIÓN nivel AMARILLO en AUTOPISTA / AUTOV...
# 2568  #RETENCIÓN nivel AMARILLO en AUTOPISTA / AUTOV...
# 2869  #RETENCIÓN nivel AMARILLO en AUTOPISTA / AUTOV...
# 2873  #RETENCIÓN nivel ROJO en AUTOPISTA / AUTOVÍA #...
# 3148  #RETENCIÓN nivel AMARILLO en AUTOPISTA / AUTOV...

# %%
# Asignación de tema 'aeropuerto'
tweets.loc[(tweets["Cluster_unig_14"] == 1) & (tweets["Cluster_unig_15"] == 5) &
           (tweets["Cluster_unibi_7"] == 3) & (tweets["Cluster_unibi_14"] == 13),
           'Topic'] = 'aeropuerto'

# %%
tweets['Topic'].value_counts()
# Out:
# otros                 22880
# sitios-madrid          1083
# tendencias-twitter      710
# trafico                 599
# buenos-dias             407
# discoteca               171
# retiro                  125
# gran-via                115
# aeropuerto              112
# followers               105
# gracias                  56
# Name: Topic, dtype: int64

# %%
tweets.loc[tweets["Topic"] == 'aeropuerto',["content"]].head()
# Out:
#                                                  content
# 8034   I'm at Aeropuerto Adolfo Suárez Madrid-Barajas...
# 9904   Pues ya estamos aquí (@ Aeropuerto Adolfo Suár...
# 10525  I'm at Aeropuerto Adolfo Suárez Madrid-Barajas...
# 10621  I'm at Aeropuerto Adolfo Suárez Madrid-Barajas...
# 10973  Back (@ Aeropuerto Adolfo Suárez Madrid-Baraja...

# %%
# Repetiremos el ejercicio de clustering con el subconjunto catalogado como 'otros', para ver que
# no hay más clústeres triviales
ot_tweets = tweets.loc[tweets["Topic"] == 'otros',["content","Latitude","Longitude"]]
ot_tweets.shape
# Out:
# (22880, 3)

# %%
ot_tweets.head()
# Out:
#                                              content  Latitude  Longitude
# 0  Regalo para socios: 'Talento a la fuga', el li...    40.416     -3.703
# 1  La recuperación del ‘ladrillo’ dispara el 144,...    40.416     -3.703
# 2  TELEVISIÓN SERIES - Cuenta atrás para conocer ...    40.416     -3.703
# 3  Nuestra taza de hoy es un homenaje a uno de lo...    40.416     -3.703
# 4              @MCadepe nos vemos el 19 de mayooo!!!    40.416     -3.703

# %%
# Extraemos los tweets y los guardamos en una lista
ot_tweets_text = ot_tweets["content"].tolist()

# %%
# Convertimos la lista en la matriz Tf-idf
vectorizer_unig_ot = TfidfVectorizer(
                max_df = 0.95,
                max_features = 30000,
                analyzer = 'word',
                tokenizer = tokenize,
                lowercase = True,
                use_idf = True,
                stop_words = spanish_stopwords,
                ngram_range=(1,1))
mx_tfidf_unig_ot = vectorizer_unig_ot.fit_transform(ot_tweets_text)

# %%
mx_tfidf_unig_ot.shape
# Out:
# (22880, 29442)

# %%
# Realización del clustering con k-means. No se detectan nuevas agrupaciones relevantes
kmeans_function(11, mx_tfidf_unig_ot, ot_tweets, vectorizer_unig_ot, "uni_ot", 3333)
# Out:
# Número de clusters: 5
# 0    12166
# 1     4933
# 3     2255
# 2     2206
# 4     1320
# Name: Cluster_uni_ot_5, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  mas
#  com
#  si
#  via
#  per
#  graci
#  dia
#  buen
#  quier
#  hac
#
# Cluster 1 : Palabras más frecuentes :
#  …
#  mas
#  hoy
#  com
#  si
#  dia
#  hac
#  mejor
#  nuestr
#  vid
#
# Cluster 2 : Palabras más frecuentes :
#  par
#  …
#  mas
#  mejor
#  dia
#  hoy
#  com
#  hac
#  nuestr
#  madr
#
# Cluster 3 : Palabras más frecuentes :
#  madr
#  in
#  …
#  españ
#  real
#  palaci
#  plaz
#  mas
#  adecc
#  dia
#
# Cluster 4 : Palabras más frecuentes :
#  tod
#  …
#  par
#  sab
#  graci
#  dias
#  buen
#  mejor
#  per
#  madr
#
#
# Número de clusters: 6
# 5    11906
# 1     4479
# 2     2296
# 4     1850
# 3     1245
# 0     1104
# Name: Cluster_uni_ot_6, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  si
#  …
#  quier
#  com
#  per
#  par
#  ver
#  pued
#  mas
#  hac
#
# Cluster 1 : Palabras más frecuentes :
#  …
#  par
#  mas
#  com
#  nuev
#  nuestr
#  mejor
#  vid
#  stigmab
#  buen
#
# Cluster 2 : Palabras más frecuentes :
#  madr
#  in
#  …
#  españ
#  real
#  palaci
#  plaz
#  mas
#  adecc
#  par
#
# Cluster 3 : Palabras más frecuentes :
#  tod
#  …
#  par
#  sab
#  graci
#  dias
#  buen
#  mejor
#  mas
#  madr
#
# Cluster 4 : Palabras más frecuentes :
#  hoy
#  dia
#  hac
#  …
#  par
#  com
#  buen
#  mas
#  feliz
#  tierr
#
# Cluster 5 : Palabras más frecuentes :
#  par
#  mas
#  com
#  via
#  graci
#  mejor
#  per
#  buen
#  nuev
#  quier
#
#
# Número de clusters: 7
# 1    11509
# 2     4570
# 3     2182
# 5     2122
# 6     1000
# 4      904
# 0      593
# Name: Cluster_uni_ot_7, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  quier
#  …
#  si
#  mas
#  com
#  per
#  hac
#  cuand
#  tod
#  ser
#
# Cluster 1 : Palabras más frecuentes :
#  mas
#  com
#  tod
#  via
#  graci
#  per
#  buen
#  mejor
#  dia
#  hac
#
# Cluster 2 : Palabras más frecuentes :
#  …
#  tod
#  mas
#  com
#  dia
#  vid
#  graci
#  hac
#  nuev
#  mejor
#
# Cluster 3 : Palabras más frecuentes :
#  madr
#  in
#  …
#  españ
#  real
#  palaci
#  plaz
#  adecc
#  mas
#  mejor
#
# Cluster 4 : Palabras más frecuentes :
#  hoy
#  …
#  dia
#  par
#  toc
#  com
#  tod
#  buen
#  h
#  madr
#
# Cluster 5 : Palabras más frecuentes :
#  par
#  …
#  tod
#  mas
#  mejor
#  nuestr
#  com
#  hac
#  madr
#  dia
#
# Cluster 6 : Palabras más frecuentes :
#  si
#  …
#  com
#  per
#  pued
#  ver
#  mas
#  tien
#  tod
#  ser
#
#
# Número de clusters: 8
# 6    11688
# 5     4480
# 3     2077
# 2     1282
# 7     1126
# 1      814
# 4      761
# 0      652
# Name: Cluster_uni_ot_8, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  buen
#  …
#  dias
#  noch
#  par
#  tod
#  com
#  viern
#  hoy
#  graci
#
# Cluster 1 : Palabras más frecuentes :
#  dia
#  …
#  hoy
#  tierr
#  par
#  feliz
#  madr
#  buen
#  libr
#  com
#
# Cluster 2 : Palabras más frecuentes :
#  mas
#  …
#  madr
#  par
#  much
#  pued
#  si
#  mejor
#  bonit
#  person
#
# Cluster 3 : Palabras más frecuentes :
#  madr
#  in
#  …
#  españ
#  palaci
#  adecc
#  real
#  plaz
#  par
#  mejor
#
# Cluster 4 : Palabras más frecuentes :
#  hac
#  …
#  par
#  com
#  si
#  mas
#  tod
#  años
#  cuand
#  falt
#
# Cluster 5 : Palabras más frecuentes :
#  …
#  par
#  com
#  hoy
#  si
#  nuev
#  nuestr
#  mejor
#  vid
#  sab
#
# Cluster 6 : Palabras más frecuentes :
#  par
#  com
#  si
#  via
#  per
#  graci
#  mejor
#  quier
#  nuev
#  hoy
#
# Cluster 7 : Palabras más frecuentes :
#  tod
#  …
#  par
#  sab
#  graci
#  list
#  per
#  mejor
#  madr
#  si
#
#
# Número de clusters: 9
# 2    9759
# 8    3651
# 0    1978
# 1    1921
# 5    1657
# 4    1299
# 6    1110
# 3     816
# 7     689
# Name: Cluster_uni_ot_9, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  madr
#  in
#  …
#  españ
#  palaci
#  real
#  adecc
#  plaz
#  estacion
#  estadi
#
# Cluster 1 : Palabras más frecuentes :
#  par
#  …
#  tod
#  mejor
#  nuestr
#  hac
#  madr
#  hoy
#  via
#  nuev
#
# Cluster 2 : Palabras más frecuentes :
#  via
#  graci
#  per
#  mejor
#  hac
#  nuev
#  quier
#  hoy
#  cuand
#  tien
#
# Cluster 3 : Palabras más frecuentes :
#  dia
#  …
#  hoy
#  tierr
#  feliz
#  madr
#  par
#  buen
#  libr
#  mas
#
# Cluster 4 : Palabras más frecuentes :
#  mas
#  …
#  much
#  madr
#  par
#  pued
#  mejor
#  person
#  bonit
#  quier
#
# Cluster 5 : Palabras más frecuentes :
#  tod
#  si
#  …
#  quier
#  sab
#  per
#  pued
#  tien
#  hac
#  porqu
#
# Cluster 6 : Palabras más frecuentes :
#  com
#  …
#  par
#  si
#  hac
#  per
#  quier
#  tod
#  hoy
#  madr
#
# Cluster 7 : Palabras más frecuentes :
#  buen
#  …
#  dias
#  noch
#  tod
#  par
#  com
#  viern
#  hoy
#  graci
#
# Cluster 8 : Palabras más frecuentes :
#  …
#  hoy
#  nuev
#  mejor
#  nuestr
#  hac
#  stigmab
#  sol
#  graci
#  vid
#
#
# Número de clusters: 10
# 0    9475
# 7    3561
# 3    2003
# 6    1888
# 8    1804
# 1    1085
# 4    1030
# 2     745
# 5     673
# 9     616
# Name: Cluster_uni_ot_10, dtype: int64
# Cluster 0 : Palabras más frecuentes :
#  via
#  dia
#  buen
#  per
#  nuev
#  quier
#  hac
#  hoy
#  tien
#  cuand
#
# Cluster 1 : Palabras más frecuentes :
#  tod
#  …
#  par
#  sab
#  dias
#  buen
#  per
#  madr
#  mund
#  hoy
#
# Cluster 2 : Palabras más frecuentes :
#  mejor
#  …
#  madr
#  par
#  sal
#  mas
#  tod
#  sab
#  mund
#  list
#
# Cluster 3 : Palabras más frecuentes :
#  madr
#  in
#  …
#  españ
#  palaci
#  real
#  plaz
#  adecc
#  dia
#  estadi
#
# Cluster 4 : Palabras más frecuentes :
#  si
#  …
#  quier
#  per
#  com
#  ver
#  pued
#  tien
#  hac
#  ser
#
# Cluster 5 : Palabras más frecuentes :
#  graci
#  …
#  segu
#  tod
#  tuitutil
#  devuelv
#  follow
#  brev
#  buen
#  mil
#
# Cluster 6 : Palabras más frecuentes :
#  par
#  …
#  dia
#  hoy
#  mas
#  hac
#  nuestr
#  com
#  nuev
#  via
#
# Cluster 7 : Palabras más frecuentes :
#  …
#  hoy
#  dia
#  nuev
#  hac
#  nuestr
#  stigmab
#  vid
#  sol
#  buen
#
# Cluster 8 : Palabras más frecuentes :
#  mas
#  com
#  …
#  hac
#  dia
#  much
#  pued
#  quier
#  per
#  hoy
#
# Cluster 9 : Palabras más frecuentes :
#  ten
#  mañan
#  …
#  par
#  hoy
#  per
#  com
#  mas
#  dia
#  sol

# %%
# Se exportan los tweets con la nueva columna a un fichero Excel
tweets[['content','Latitude','Longitude','Topic']].to_excel('ficheros/TweetsConTopic/tweets_spainGeo_topic.xlsx', header=True, index=False)

# %% [markdown]
# ## 3. Topic modeling con LDA

# %%
# Se redefine la función de tokenización para tener en cuenta las palabras de parada, sin hacer stemming
# (para tener más términos para buscar los temas)
def tokenize_stop(text):
    # Eliminamos lo que no sean palabras
    text = ''.join([c for c in text if c not in non_words])
    # Eliminamos las palabras de parada
    text = ''.join([c for c in text if c not in spanish_stopwords])

    # Tokenización
    tokens = tknzr.tokenize(text)
    
    return tokens

# %%
# Generamos una lista de tweets donde cada tweet sea una lista de palabras
words_tweet = [tokenize_stop(tweet) for tweet in tweets_text]
# Se genera el diccionario
dictionary = corpora.Dictionary(words_tweet)
# Se convierte el diccionario en BOW (Bag of Words)
tweet_term_matrix = [dictionary.doc2bow(doc) for doc in words_tweet]
# Lanzamos el modelo (tarda bastante, más de 1 hora)
ldamodel = models.ldamodel.LdaModel(tweet_term_matrix, num_topics=8, id2word = dictionary, passes=100)

# Impresión de resultados (no hay mucha precisión en los resultados; sólo está claro el tema de 'trafico',
# que es el Topic 5, y hay ciertos indicios del tema 'tendencias' y 'aeropuerto' en el Topic 7, pero no
# se distinguen).
for topic in ldamodel.show_topics(num_topics=10, formatted=False, num_words=10):
    print("Topic {}: Words: ".format(topic[0]))
    topicwords = [w for (w, val) in topic[1]]
    print(topicwords)
# Out:
# Topic 0: Words:
# ['d', 'l', 'dl', 'Mdrid', '…', 'ls', 'El', 'n', 'cn', 'un']
# Topic 1: Words:
# ['d', 'l', 'n', '…', 'pr', 'qu', 'ls', 'un', 'nivl', 's']
# Topic 2: Words:
# ['Mdrid', 'in', 'd', 'n', 'l', 'D', 'ls', 'cn', '…', 'Sl']
# Topic 3: Words:
# ['l', 'qu', 's', 'n', '…', 'd', 'pr', 'un', 'ls', 'm']
# Topic 4: Words:
# ['…', 'd', 'l', 'n', 'pr', 'cn', 'ES', 'Stigmbs', 'Mdrid', 'L']
# Topic 5: Words:
# ['n', 'l', 'DGT', 'pk', 'DGTMdrid', 'RETENCIÓN', 'AUTOPISTA', 'AUTOVÍA', 'AMARILLO', 'A']
# Topic 6: Words:
# ['…', 'd', 'dís', 'Buns', 'mdrid', 'pr', 'fin', 'smn', 'ls', 'virns']
# Topic 7: Words:
# ['Mdrid', 'n', 'un', 's', 'hr', 'tndnci', 't', 'Im', 'd', 'Arpurt']

# %%
# Se repetirá el proceso haciendo también stemming.
words_tweet_stem = [tokenize(tweet) for tweet in tweets_text]
dictionary_stem = corpora.Dictionary(words_tweet_stem)
tweet_term_matrix_stem = [dictionary_stem.doc2bow(doc) for doc in words_tweet_stem]
ldamodel_stem = models.ldamodel.LdaModel(tweet_term_matrix_stem, num_topics=8, id2word = dictionary_stem, passes=100)

# Impresión de resultados (no hay mucha precisión en los resultados nuevamente; el único claro vuelve a ser
# 'trafico', que es el Topic 7).
for topic_stem in ldamodel_stem.show_topics(num_topics=10, formatted=False, num_words=10):
    print("Topic {}: Words: ".format(topic_stem[0]))
    topicwords_stem = [w for (w, val) in topic_stem[1]]
    print(topicwords_stem)
# Out:
# Topic 0: Words:
# ['de', 'buen', 'a', 'dias', 'palaci', 'el', 'un', 'los', 'graci', 'adolf']
# Topic 1: Words:
# ['que', 'no', '…', 'lo', 'y', 'a', 'te', 'es', 'spain', 'si']
# Topic 2: Words:
# ['…', 'y', 'de', 'con', 'dia', 'del', 'el', 'madr', 'par', 'un']
# Topic 3: Words:
# ['de', 'la', 'el', 'en', '…', 'a', 'y', 'los', 'que', 'las']
# Topic 4: Words:
# ['de', '…', 'la', 'y', 'que', 'a', 'el', 'me', 'en', 'mi']
# Topic 5: Words:
# ['de', 'madr', 'la', 'el', 'en', 'in', '…', 'del', 'españ', 'las']
# Topic 6: Words:
# ['en', 'es', 'una', 'ahor', 'madr', 'tendenci', 'nuev', 'estadi', 'aeropuert', 'suarez']
# Topic 7: Words:
# ['en', 'al', 'nivel', 'pk', 'dgt', 'retencion', 'dgtmadr', 'autop', 'autov', 'amarill']

# %% [markdown]
# <hr>

# %% [markdown]
# ## Licencia

# %% [markdown]
# El notebook está licenciado libremente bajo la licencia [Creative Commons Attribution Share-Alike](https://creativecommons.org/licenses/by/2.0/).
#
# La base del código empleado procede del trabajo de Yogesh Kulkarni llamado [Sentiment Analysis of Twitter Posts on Chennai Floods using Python](https://www.analyticsvidhya.com/blog/2017/01/sentiment-analysis-of-twitter-posts-on-chennai-floods-using-python/) y del trabajo de Brandon Rose llamado [Document Clustering with Python](http://brandonrose.org/clustering)
#
# © 2017 - Juan Bermudo Mera, Margarita Bolívar Jiménez, Lourdes Fernández Nieto, Ramón Pérez Hernández.
#
# Universidad Politécnica de Madrid.
